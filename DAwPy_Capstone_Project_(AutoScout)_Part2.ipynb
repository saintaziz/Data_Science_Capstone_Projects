# %% [markdown]
# # PART- 2 `( Handling With Missing Values )`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches
import seaborn as sns

import warnings

# Statistics functions
from scipy.stats import norm
from scipy import stats
from scipy.stats import chi2_contingency
from scipy.stats import chi2
# Out:
# /Users/saint/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Suppressing a warning 
warnings.filterwarnings("ignore") 

# It is a magic function that renders the figure in the notebook
# %matplotlib inline 

# Changing the figure size of a seaborn axes 
sns.set(rc={"figure.figsize": (10, 6)})

# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid")

# To display maximum columns
pd.set_option('display.max_columns', None)

# To display maximum columns
# pd.set_option('display.max_rows', None)

# %%
import re 

def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/][\\n''', diff_value=list()):  
    diff_value.clear()
    column = Series.dropna().apply(str).str.strip(strip)
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %%
df = pd.read_csv("cleaned_autoscout.csv")
df.head()
# Out:
#                                    short_description body_type  price_€  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770.0
# 1                                     1.8 TFSI sport    Sedans  14500.0
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640.0
# 3                            1.4 TDi Design S tronic    Sedans  14500.0
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790.0
#
#                 vat       km  registration  prev_owner  hp_kW  type  \
# 0    VAT deductible  56013.0        2016.0         2.0   66.0  Used
# 1  Price negotiable  80000.0        2017.0         NaN  141.0  Used
# 2    VAT deductible  83450.0        2016.0         1.0   85.0  Used
# 3               NaN  73000.0        2016.0         1.0   66.0  Used
# 4               NaN  16200.0        2016.0         1.0   66.0  Used
#
#    previous_owners  warranty  make model body_color paint_type  \
# 0              2.0       NaN  Audi    A1      Black   Metallic
# 1              NaN       NaN  Audi    A1        Red        NaN
# 2              1.0       NaN  Audi    A1      Black   Metallic
# 3              1.0       NaN  Audi    A1      Brown   Metallic
# 4              1.0       NaN  Audi    A1      Black   Metallic
#
#       body_color_original upholstery  nr_of_doors  nr_of_seats gearing_type  \
# 0           Mythosschwarz      Cloth          5.0          5.0    Automatic
# 1                     NaN      Cloth          3.0          4.0    Automatic
# 2  mythosschwarz metallic      Cloth          4.0          4.0    Automatic
# 3                     NaN        NaN          3.0          4.0    Automatic
# 4  Mythosschwarz Metallic      Cloth          5.0          5.0    Automatic
#
#    engine_displacement_cc  cylinders  weight_kg drive_chain     fuel  co2e_g  \
# 0                  1422.0        3.0     1220.0       front   Diesel    99.0
# 1                  1798.0        4.0     1255.0       front  Benzine   129.0
# 2                  1598.0        NaN        NaN       front   Diesel    99.0
# 3                  1422.0        3.0     1195.0         NaN   Diesel    99.0
# 4                  1422.0        3.0        NaN       front   Diesel   109.0
#
#   emission_class                                comfort&convenience  \
# 0         Euro 6  Air conditioning,Armrest,Automatic climate con...
# 1         Euro 6  Air conditioning,Automatic climate control,Hil...
# 2         Euro 6  Air conditioning,Cruise control,Electrical sid...
# 3         Euro 6  Air suspension,Armrest,Auxiliary heating,Elect...
# 4         Euro 6  Air conditioning,Armrest,Automatic climate con...
#
#                                  entertainment&media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                      safety&security  gears country_version  \
# 0  ABS,Central door lock,Daytime running lights,D...    NaN             NaN
# 1  ABS,Central door lock,Central door lock with r...    7.0             NaN
# 2  ABS,Central door lock,Daytime running lights,D...    NaN             NaN
# 3  ABS,Alarm system,Central door lock with remote...    6.0             NaN
# 4  ABS,Central door lock,Driver-side airbag,Elect...    NaN         Germany
#
#    consumption_comb  consumption_city  consumption_country
# 0               3.8               4.3                  3.5
# 1               5.6               7.1                  4.7
# 2               3.8               4.4                  3.4
# 3               3.8               4.3                  3.5
# 4               4.1               4.6                  3.8

# %%
df.shape
# Out:
# (15919, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   short_description       15873 non-null  object
#  1   body_type               15859 non-null  object
#  2   price_€                 15919 non-null  float64
#  3   vat                     11406 non-null  object
#  4   km                      14895 non-null  float64
#  5   registration            14322 non-null  float64
#  6   prev_owner              9091 non-null   float64
#  7   hp_kW                   15831 non-null  float64
#  8   type                    15917 non-null  object
#  9   previous_owners         9279 non-null   float64
#  10  warranty                4853 non-null   float64
#  11  make                    15919 non-null  object
#  12  model                   15919 non-null  object
#  13  body_color              15322 non-null  object
#  14  paint_type              10147 non-null  object
#  15  body_color_original     12145 non-null  object
#  16  upholstery              12199 non-null  object
#  17  nr_of_doors             15707 non-null  float64
#  18  nr_of_seats             14942 non-null  float64
#  19  gearing_type            15919 non-null  object
#  20  engine_displacement_cc  15423 non-null  float64
#  21  cylinders               10239 non-null  float64
#  22  weight_kg               8945 non-null   float64
#  23  drive_chain             9061 non-null   object
#  24  fuel                    15919 non-null  object
#  25  co2e_g                  13477 non-null  float64
#  26  emission_class          12291 non-null  object
#  27  comfort&convenience     14999 non-null  object
#  28  entertainment&media     14545 non-null  object
#  29  extras                  12957 non-null  object
#  30  safety&security         14937 non-null  object
#  31  gears                   11207 non-null  float64
#  32  country_version         7586 non-null   object
#  33  consumption_comb        12129 non-null  float64
#  34  consumption_city        11880 non-null  float64
#  35  consumption_country     12554 non-null  float64
# dtypes: float64(17), object(19)
# memory usage: 4.4+ MB

# %%
df.isnull().sum()
# Out:
# short_description            46
# body_type                    60
# price_€                       0
# vat                        4513
# km                         1024
# registration               1597
# prev_owner                 6828
# hp_kW                        88
# type                          2
# previous_owners            6640
# warranty                  11066
# make                          0
# model                         0
# body_color                  597
# paint_type                 5772
# body_color_original        3774
# upholstery                 3720
# nr_of_doors                 212
# nr_of_seats                 977
# gearing_type                  0
# engine_displacement_cc      496
# cylinders                  5680
# weight_kg                  6974
# drive_chain                6858
# fuel                          0
# co2e_g                     2442
# emission_class             3628
# comfort&convenience         920
# entertainment&media        1374
# extras                     2962
# safety&security             982
# gears                      4712
# country_version            8333
# consumption_comb           3790
# consumption_city           4039
# consumption_country        3365
# dtype: int64

# %%
#df.duplicated().sum()

# %%
#df.drop_duplicates(keep="first", inplace=True, ignore_index=True)

# %%
df.isnull().sum()
# Out:
# short_description            46
# body_type                    60
# price_€                       0
# vat                        4513
# km                         1024
# registration               1597
# prev_owner                 6828
# hp_kW                        88
# type                          2
# previous_owners            6640
# warranty                  11066
# make                          0
# model                         0
# body_color                  597
# paint_type                 5772
# body_color_original        3774
# upholstery                 3720
# nr_of_doors                 212
# nr_of_seats                 977
# gearing_type                  0
# engine_displacement_cc      496
# cylinders                  5680
# weight_kg                  6974
# drive_chain                6858
# fuel                          0
# co2e_g                     2442
# emission_class             3628
# comfort&convenience         920
# entertainment&media        1374
# extras                     2962
# safety&security             982
# gears                      4712
# country_version            8333
# consumption_comb           3790
# consumption_city           4039
# consumption_country        3365
# dtype: int64

# %%
df.describe().T
# Out:
#                           count          mean           std     min      25%  \
# price_€                 15919.0  18019.896727   7386.169409    13.0  12850.0
# km                      14895.0  34130.127828  37352.977568     0.0   5153.0
# registration            14322.0   2017.457618      1.076917  2016.0   2016.0
# prev_owner               9091.0      1.089979      0.294877     1.0      1.0
# hp_kW                   15831.0     88.367696     26.835135     1.0     66.0
# previous_owners          9279.0      1.067895      0.329812     0.0      1.0
# warranty                 4853.0     21.927261     15.771120     1.0     12.0
# nr_of_doors             15707.0      4.656077      0.645298     1.0      4.0
# nr_of_seats             14942.0      4.949873      0.489872     2.0      5.0
# engine_displacement_cc  15423.0   1423.540881    333.530658     1.0   1229.0
# cylinders               10239.0      3.797343      0.415382     1.0      4.0
# weight_kg                8945.0   1351.106540    220.661532     1.0   1165.0
# co2e_g                  13477.0    123.793574    270.000389    14.0    104.0
# gears                   11207.0      5.924601      0.848158     1.0      5.0
# consumption_comb        12129.0      4.860722      0.906300     1.2      4.2
# consumption_city        11880.0      5.973047      1.409315     3.3      4.7
# consumption_country     12554.0      4.214107      0.675568     2.9      3.7
#
#                             50%      75%       max
# price_€                 16900.0  21900.0   74600.0
# km                      22740.0  49371.5  317000.0
# registration             2018.0   2018.0    2019.0
# prev_owner                  1.0      1.0       4.0
# hp_kW                      85.0    101.0     294.0
# previous_owners             1.0      1.0       4.0
# warranty                   12.0     24.0      72.0
# nr_of_doors                 5.0      5.0       7.0
# nr_of_seats                 5.0      5.0       7.0
# engine_displacement_cc   1461.0   1598.0   16000.0
# cylinders                   4.0      4.0       8.0
# weight_kg                1288.0   1487.0    2471.0
# co2e_g                    116.0    129.0   14457.0
# gears                       6.0      6.0      50.0
# consumption_comb            4.8      5.5      13.8
# consumption_city            5.8      7.1      19.9
# consumption_country         4.2      4.6      10.3

# %%
df.describe(include="O").T
# Out:
#                      count unique  \
# short_description    15873  10001
# body_type            15859      9
# vat                  11406      2
# type                 15917      5
# make                 15919      3
# model                15919      9
# body_color           15322     14
# paint_type           10147      3
# body_color_original  12145   1926
# upholstery           12199      6
# gearing_type         15919      3
# drive_chain           9061      3
# fuel                 15919      4
# emission_class       12291      6
# comfort&convenience  14999   6198
# entertainment&media  14545    346
# extras               12957    659
# safety&security      14937   4443
# country_version       7586     23
#
#                                                                    top   freq
# short_description                    SPB 1.6 TDI 116 CV S tronic Sport     64
# body_type                                                       Sedans   7903
# vat                                                     VAT deductible  10980
# type                                                              Used  11096
# make                                                              Opel   7343
# model                                                               A3   3097
# body_color                                                       Black   3745
# paint_type                                                    Metallic   9794
# body_color_original                                       Onyx Schwarz    338
# upholstery                                                       Cloth   9206
# gearing_type                                                    Manual   8153
# drive_chain                                                      front   8886
# fuel                                                           Benzine   8551
# emission_class                                                  Euro 6  10139
# comfort&convenience  Air conditioning,Electrical side mirrors,Hill ...    216
# entertainment&media  Bluetooth,Hands-free equipment,On-board comput...   1282
# extras                                                    Alloy wheels   3245
# safety&security      ABS,Central door lock,Daytime running lights,D...    538
# country_version                                                Germany   4502

# %%
df["price_€"].sort_values()
# Out:
# 8594        13.0
# 8828       120.0
# 6066       255.0
# 8829       331.0
# 8827      4950.0
#           ...
# 15828    64332.0
# 3587     64900.0
# 3649     67600.0
# 15826    68320.0
# 3648     74600.0
# Name: price_€, Length: 15919, dtype: float64

# %%
df["age"] = 2019 - df.registration

# %%
df.drop(columns=["registration", "short_description"], inplace=True)

# %%
# we created age column we don't need to registiration column anymore. Also we don't need short_description too we droped.

# %%
def check_df(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print(df[col].value_counts(dropna = False))
    print("*"*30)
    print("\n\n")

# %% [markdown]
# ## body_type

# %%
check_df("body_type")
# Out:
# column name :  body_type
# --------------------------------
# Per_of_Nulls   :  % 0.38
# Num_of_Nulls   :  60
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
# ******************************

# %%
df[df.body_type.isnull()]
# Out:
#       body_type  price_€               vat        km  prev_owner  hp_kW  \
# 3175        NaN  14400.0               NaN  119000.0         1.0   81.0
# 3255        NaN  18500.0  Price negotiable   70000.0         NaN   81.0
# 3975        NaN  19950.0               NaN   25000.0         2.0   85.0
# 3997        NaN  19750.0    VAT deductible   38800.0         1.0   82.0
# 4206        NaN  18490.0               NaN   20000.0         NaN   92.0
# 4297        NaN  17990.0               NaN   20000.0         NaN   92.0
# 4298        NaN  17990.0               NaN   20000.0         NaN   92.0
# 5718        NaN  12990.0               NaN   47000.0         NaN  100.0
# 5938        NaN  12990.0               NaN   47000.0         NaN  100.0
# 5940        NaN  12990.0               NaN   47000.0         NaN  100.0
# 6920        NaN  11990.0               NaN   64000.0         NaN   81.0
# 6922        NaN  11990.0               NaN   64000.0         NaN   81.0
# 6927        NaN  11990.0               NaN   64000.0         NaN   81.0
# 7709        NaN  26490.0               NaN    6000.0         NaN  112.0
# 8408        NaN  12435.0    VAT deductible   21050.0         1.0   44.0
# 8584        NaN   8900.0               NaN   43731.0         NaN   51.0
# 10837       NaN  11490.0               NaN   99000.0         NaN  125.0
# 10838       NaN  11490.0               NaN   99000.0         NaN  125.0
# 10857       NaN  11490.0               NaN   99000.0         NaN  125.0
# 13430       NaN   7990.0    VAT deductible   76021.0         NaN   67.0
# 13470       NaN   8490.0               NaN   39990.0         NaN   55.0
# 13576       NaN   7980.0    VAT deductible   79980.0         1.0   56.0
# 13703       NaN   7690.0    VAT deductible   63372.0         NaN   56.0
# 13725       NaN   7490.0    VAT deductible   69031.0         NaN   56.0
# 13852       NaN   8500.0               NaN   34564.0         NaN   55.0
# 13900       NaN   9490.0    VAT deductible   84496.0         NaN   56.0
# 14107       NaN   9990.0               NaN   39000.0         NaN   55.0
# 14124       NaN   9990.0    VAT deductible      15.0         1.0   56.0
# 14127       NaN   9990.0    VAT deductible      15.0         1.0   56.0
# 14134       NaN   9980.0    VAT deductible      10.0         NaN   56.0
# 14135       NaN   9980.0    VAT deductible      10.0         NaN   56.0
# 14480       NaN  10000.0               NaN    8000.0         NaN   54.0
# 14869       NaN  10850.0    VAT deductible      10.0         NaN   56.0
# 14870       NaN  10850.0    VAT deductible      10.0         NaN   56.0
# 14928       NaN  17500.0               NaN  141000.0         NaN  118.0
# 14990       NaN  26800.0               NaN     332.0         NaN  165.0
# 15058       NaN  24990.0               NaN   45000.0         NaN  118.0
# 15059       NaN  24990.0               NaN   45000.0         NaN  118.0
# 15060       NaN  24990.0               NaN   45000.0         NaN  118.0
# 15124       NaN  24500.0               NaN   58078.0         NaN  118.0
# 15269       NaN  17500.0               NaN  141000.0         NaN  118.0
# 15275       NaN  17500.0               NaN  141000.0         NaN  118.0
# 15289       NaN  28140.0               NaN      10.0         NaN   96.0
# 15307       NaN  31000.0               NaN      10.0         NaN   96.0
# 15378       NaN  26450.0               NaN      10.0         NaN   96.0
# 15437       NaN  33000.0    VAT deductible       NaN         NaN  118.0
# 15452       NaN  33300.0               NaN      10.0         NaN  118.0
# 15456       NaN  33400.0               NaN     886.0         NaN  118.0
# 15457       NaN  33400.0               NaN     454.0         NaN  118.0
# 15488       NaN  32600.0               NaN      10.0         NaN  165.0
# 15489       NaN  32576.0    VAT deductible   10100.0         1.0  118.0
# 15491       NaN  32576.0    VAT deductible   10100.0         1.0  118.0
# 15499       NaN  32200.0               NaN      10.0         NaN  165.0
# 15544       NaN  29750.0               NaN      10.0         NaN  165.0
# 15556       NaN  30160.0               NaN      10.0         NaN  118.0
# 15589       NaN  31000.0    VAT deductible       NaN         NaN  118.0
# 15696       NaN  38200.0    VAT deductible       1.0         NaN  118.0
# 15712       NaN  37100.0    VAT deductible       1.0         NaN  118.0
# 15736       NaN  35448.0               NaN      10.0         NaN  165.0
# 15770       NaN  35930.0               NaN      10.0         NaN  118.0
#
#                  type  previous_owners  warranty     make     model  \
# 3175             Used              1.0       NaN     Audi        A3
# 3255             Used              NaN       NaN     Audi        A3
# 3975             Used              2.0       NaN     Audi        A3
# 3997             Used              1.0       6.0     Audi        A3
# 4206             Used              NaN       NaN     Audi        A3
# 4297             Used              NaN       NaN     Audi        A3
# 4298             Used              NaN       NaN     Audi        A3
# 5718             Used              NaN       NaN     Opel     Astra
# 5938             Used              NaN       NaN     Opel     Astra
# 5940             Used              NaN       NaN     Opel     Astra
# 6920             Used              NaN       NaN     Opel     Astra
# 6922             Used              NaN       NaN     Opel     Astra
# 6927             Used              NaN       NaN     Opel     Astra
# 7709             Used              NaN       NaN     Opel     Astra
# 8408             Used              1.0       NaN     Opel     Corsa
# 8584             Used              NaN       NaN     Opel     Corsa
# 10837            Used              NaN       NaN     Opel  Insignia
# 10838            Used              NaN       NaN     Opel  Insignia
# 10857            Used              NaN       NaN     Opel  Insignia
# 13430            Used              NaN       NaN  Renault      Clio
# 13470            Used              NaN       NaN  Renault      Clio
# 13576            Used              1.0       3.0  Renault      Clio
# 13703            Used              NaN       6.0  Renault      Clio
# 13725            Used              NaN       6.0  Renault      Clio
# 13852            Used              NaN       NaN  Renault      Clio
# 13900            Used              NaN       NaN  Renault      Clio
# 14107            Used              NaN       NaN  Renault      Clio
# 14124            Used              1.0       NaN  Renault      Clio
# 14127            Used              1.0       NaN  Renault      Clio
# 14134            Used              NaN       NaN  Renault      Clio
# 14135            Used              NaN       NaN  Renault      Clio
# 14480            Used              NaN       NaN  Renault      Clio
# 14869             New              NaN       NaN  Renault      Clio
# 14870             New              NaN       NaN  Renault      Clio
# 14928            Used              NaN       NaN  Renault    Espace
# 14990            Used              NaN       NaN  Renault    Espace
# 15058            Used              NaN       NaN  Renault    Espace
# 15059            Used              NaN       NaN  Renault    Espace
# 15060            Used              NaN       NaN  Renault    Espace
# 15124            Used              NaN       NaN  Renault    Espace
# 15269            Used              NaN       NaN  Renault    Espace
# 15275            Used              NaN       NaN  Renault    Espace
# 15289            Used              NaN       NaN  Renault    Espace
# 15307            Used              NaN       NaN  Renault    Espace
# 15378            Used              NaN       NaN  Renault    Espace
# 15437  Pre-registered              NaN       NaN  Renault    Espace
# 15452            Used              NaN       NaN  Renault    Espace
# 15456            Used              NaN       NaN  Renault    Espace
# 15457            Used              NaN       NaN  Renault    Espace
# 15488            Used              NaN       NaN  Renault    Espace
# 15489            Used              1.0       NaN  Renault    Espace
# 15491            Used              1.0       NaN  Renault    Espace
# 15499            Used              NaN       NaN  Renault    Espace
# 15544            Used              NaN       NaN  Renault    Espace
# 15556            Used              NaN       NaN  Renault    Espace
# 15589  Pre-registered              NaN       NaN  Renault    Espace
# 15696  Pre-registered              NaN       NaN  Renault    Espace
# 15712  Pre-registered              NaN       NaN  Renault    Espace
# 15736            Used              NaN       NaN  Renault    Espace
# 15770            Used              NaN       NaN  Renault    Espace
#
#       body_color paint_type             body_color_original    upholstery  \
# 3175       Black   Metallic                             NaN         Cloth
# 3255       White        NaN                             NaN         Cloth
# 3975        Blue   Metallic                             NaN           NaN
# 3997       Black        NaN                            NOIR           NaN
# 4206       White        NaN                             NaN           NaN
# 4297       White        NaN                             NaN           NaN
# 4298       White        NaN                             NaN           NaN
# 5718       Black        NaN                             NaN           NaN
# 5938       Black        NaN                             NaN           NaN
# 5940       Black        NaN                             NaN           NaN
# 6920       Black        NaN                             NaN           NaN
# 6922       Black        NaN                             NaN           NaN
# 6927       Black        NaN                             NaN           NaN
# 7709        Grey        NaN                   Gris Cosmique           NaN
# 8408       White        NaN  SchneeWeiss/SummitWhite/Arctic         Cloth
# 8584       Black        NaN                             NaN           NaN
# 10837      Black        NaN                             NaN           NaN
# 10838      Black        NaN                             NaN           NaN
# 10857      Black        NaN                             NaN           NaN
# 13430      White        NaN                           BLANC           NaN
# 13470      White        NaN                             NaN           NaN
# 13576      White        NaN                   BLANC GLACIER           NaN
# 13703      White        NaN                           BLANC           NaN
# 13725      White        NaN                           BLANC           NaN
# 13852      White        NaN                          Bianco           NaN
# 13900      White        NaN                           BLANC           NaN
# 14107      White        NaN                             NaN           NaN
# 14124      White        NaN                         BLANCHE           NaN
# 14127      White        NaN                         BLANCHE           NaN
# 14134      White        NaN                    BLANC GLACIE           NaN
# 14135      White        NaN                    BLANC GLACIE           NaN
# 14480        Red        NaN                             NaN         Cloth
# 14869       Grey   Metallic                   titangraumet.         Cloth
# 14870      Black   Metallic                     schwarzmet.         Cloth
# 14928      White        NaN                             NaN           NaN
# 14990       Grey        NaN                  Gris Cassiopée           NaN
# 15058      White        NaN                             NaN           NaN
# 15059      White        NaN                             NaN           NaN
# 15060      White        NaN                             NaN           NaN
# 15124       Grey        NaN                  Gris Cassiopée           NaN
# 15269      White        NaN                             NaN           NaN
# 15275      White        NaN                             NaN           NaN
# 15289       Grey        NaN                            Gris           NaN
# 15307       Grey        NaN                            Gris           NaN
# 15378       Grey        NaN                            Gris           NaN
# 15437      Black   Metallic                            Nero           NaN
# 15452       Grey        NaN                            Gris           NaN
# 15456      Black        NaN                     Noir Etoilé           NaN
# 15457      White        NaN                     Blanc Nacré           NaN
# 15488       Grey        NaN                            Gris           NaN
# 15489      Black   Metallic                             NaN  Full leather
# 15491      Black   Metallic                             NaN  Full leather
# 15499       Grey        NaN                            Gris           NaN
# 15544       Grey        NaN                            Gris           NaN
# 15556       Grey        NaN                            Gris           NaN
# 15589      White   Metallic                          Bianco           NaN
# 15696      Black   Metallic                            Nero           NaN
# 15712      White   Metallic                          Bianco           NaN
# 15736       Grey        NaN                            Gris           NaN
# 15770       Grey        NaN                            Gris           NaN
#
#        nr_of_doors  nr_of_seats gearing_type  engine_displacement_cc  \
# 3175           5.0          5.0       Manual                  1598.0
# 3255           3.0          5.0    Automatic                  1598.0
# 3975           5.0          5.0    Automatic                   999.0
# 3997           3.0          NaN    Automatic                  1598.0
# 4206           5.0          NaN       Manual                     NaN
# 4297           5.0          NaN       Manual                     NaN
# 4298           5.0          NaN       Manual                     NaN
# 5718           5.0          NaN    Automatic                     NaN
# 5938           5.0          NaN    Automatic                     NaN
# 5940           5.0          NaN    Automatic                     NaN
# 6920           5.0          NaN       Manual                     NaN
# 6922           5.0          NaN       Manual                     NaN
# 6927           5.0          NaN       Manual                     NaN
# 7709           5.0          NaN    Automatic                     NaN
# 8408           5.0          5.0    Automatic                  1364.0
# 8584           NaN          NaN    Automatic                     NaN
# 10837          5.0          NaN    Automatic                     NaN
# 10838          5.0          NaN    Automatic                     NaN
# 10857          5.0          NaN    Automatic                     NaN
# 13430          5.0          NaN       Manual                  1461.0
# 13470          5.0          NaN       Manual                     NaN
# 13576          5.0          NaN       Manual                  1461.0
# 13703          5.0          NaN       Manual                  1461.0
# 13725          5.0          NaN       Manual                  1461.0
# 13852          5.0          NaN       Manual                  1461.0
# 13900          5.0          NaN       Manual                  1461.0
# 14107          5.0          NaN       Manual                     NaN
# 14124          5.0          NaN       Manual                  1461.0
# 14127          5.0          NaN       Manual                  1461.0
# 14134          5.0          NaN       Manual                  1461.0
# 14135          5.0          NaN       Manual                  1461.0
# 14480          5.0          5.0       Manual                     NaN
# 14869          5.0          5.0       Manual                   898.0
# 14870          5.0          5.0       Manual                   898.0
# 14928          5.0          NaN    Automatic                     NaN
# 14990          5.0          NaN    Automatic                  1798.0
# 15058          5.0          NaN    Automatic                     NaN
# 15059          5.0          NaN    Automatic                     NaN
# 15060          5.0          NaN    Automatic                     NaN
# 15124          5.0          NaN    Automatic                  1598.0
# 15269          5.0          NaN    Automatic                     NaN
# 15275          5.0          NaN    Automatic                     NaN
# 15289          5.0          NaN       Manual                  1598.0
# 15307          5.0          NaN       Manual                  1598.0
# 15378          5.0          NaN       Manual                  1598.0
# 15437          5.0          7.0    Automatic                  1598.0
# 15452          5.0          NaN    Automatic                  1598.0
# 15456          5.0          NaN    Automatic                  1598.0
# 15457          5.0          NaN    Automatic                  1598.0
# 15488          5.0          NaN    Automatic                  1798.0
# 15489          5.0          7.0    Automatic                  1598.0
# 15491          5.0          7.0    Automatic                  1598.0
# 15499          5.0          NaN    Automatic                  1798.0
# 15544          5.0          NaN    Automatic                  1798.0
# 15556          5.0          NaN    Automatic                  1598.0
# 15589          5.0          7.0    Automatic                  1598.0
# 15696          5.0          7.0    Automatic                  1598.0
# 15712          5.0          7.0    Automatic                  1598.0
# 15736          5.0          NaN    Automatic                  1798.0
# 15770          5.0          NaN    Automatic                  1598.0
#
#        cylinders  weight_kg drive_chain     fuel  co2e_g emission_class  \
# 3175         4.0     1385.0         NaN   Diesel    99.0         Euro 6
# 3255         4.0     1255.0         NaN   Diesel    99.0         Euro 6
# 3975         3.0     1275.0         NaN  Benzine   107.0         Euro 6
# 3997         NaN        NaN         NaN   Diesel     NaN            NaN
# 4206         NaN        NaN         NaN  Benzine   117.0            NaN
# 4297         NaN        NaN         NaN  Benzine   117.0            NaN
# 4298         NaN        NaN         NaN  Benzine   117.0            NaN
# 5718         NaN        NaN         NaN   Diesel   119.0            NaN
# 5938         NaN        NaN         NaN   Diesel   119.0            NaN
# 5940         NaN        NaN         NaN   Diesel   119.0            NaN
# 6920         NaN        NaN         NaN   Diesel    97.0            NaN
# 6922         NaN        NaN         NaN   Diesel    97.0            NaN
# 6927         NaN        NaN         NaN   Diesel    97.0            NaN
# 7709         NaN        NaN         NaN  Benzine     NaN            NaN
# 8408         4.0        NaN         NaN  Benzine     NaN            NaN
# 8584         NaN        NaN         NaN  Benzine     NaN            NaN
# 10837        NaN        NaN         NaN   Diesel   147.0            NaN
# 10838        NaN        NaN         NaN   Diesel   147.0            NaN
# 10857        NaN        NaN         NaN   Diesel   147.0            NaN
# 13430        NaN        NaN         NaN   Diesel     NaN            NaN
# 13470        NaN        NaN         NaN  Benzine     NaN            NaN
# 13576        NaN        NaN         NaN   Diesel     NaN            NaN
# 13703        NaN        NaN         NaN   Diesel     NaN            NaN
# 13725        NaN        NaN         NaN   Diesel     NaN            NaN
# 13852        4.0        NaN         NaN   Diesel     NaN            NaN
# 13900        NaN        NaN         NaN   Diesel     NaN            NaN
# 14107        NaN        NaN         NaN   Diesel    85.0            NaN
# 14124        NaN        NaN         NaN   Diesel     NaN            NaN
# 14127        NaN        NaN         NaN   Diesel     NaN            NaN
# 14134        NaN        NaN         NaN   Diesel     NaN            NaN
# 14135        NaN        NaN         NaN   Diesel     NaN            NaN
# 14480        5.0     1134.0         NaN  Benzine   127.0         Euro 4
# 14869        NaN     1165.0         NaN  Benzine   114.0        Euro 6c
# 14870        NaN     1165.0         NaN  Benzine   114.0        Euro 6c
# 14928        NaN        NaN         NaN   Diesel   120.0            NaN
# 14990        4.0        NaN         NaN  Benzine   152.0            NaN
# 15058        NaN        NaN         NaN   Diesel   120.0            NaN
# 15059        NaN        NaN         NaN   Diesel   120.0            NaN
# 15060        NaN        NaN         NaN   Diesel   120.0            NaN
# 15124        4.0        NaN         NaN   Diesel   120.0            NaN
# 15269        NaN        NaN         NaN   Diesel   120.0            NaN
# 15275        NaN        NaN         NaN   Diesel   120.0            NaN
# 15289        4.0        NaN         NaN   Diesel   116.0            NaN
# 15307        4.0        NaN         NaN   Diesel   116.0            NaN
# 15378        4.0        NaN         NaN   Diesel   116.0            NaN
# 15437        4.0        NaN         NaN   Diesel   123.0         Euro 6
# 15452        4.0        NaN         NaN   Diesel   120.0            NaN
# 15456        4.0        NaN         NaN   Diesel   120.0            NaN
# 15457        4.0        NaN         NaN   Diesel   120.0            NaN
# 15488        4.0        NaN         NaN  Benzine     NaN            NaN
# 15489        4.0     1734.0       front   Diesel   120.0            NaN
# 15491        4.0     1734.0       front   Diesel   120.0            NaN
# 15499        4.0        NaN         NaN  Benzine     NaN            NaN
# 15544        4.0        NaN         NaN  Benzine     NaN            NaN
# 15556        4.0        NaN         NaN   Diesel   120.0            NaN
# 15589        4.0        NaN         NaN   Diesel   123.0         Euro 6
# 15696        4.0        NaN         NaN   Diesel   123.0         Euro 6
# 15712        4.0        NaN         NaN   Diesel   123.0         Euro 6
# 15736        4.0        NaN         NaN  Benzine     NaN            NaN
# 15770        4.0        NaN         NaN   Diesel   120.0            NaN
#
#                                      comfort&convenience  \
# 3175   Air conditioning,Armrest,Automatic climate con...
# 3255   Air conditioning,Armrest,Automatic climate con...
# 3975   Air conditioning,Armrest,Automatic climate con...
# 3997   Air conditioning,Automatic climate control,Cru...
# 4206                                    Air conditioning
# 4297                                    Air conditioning
# 4298                                    Air conditioning
# 5718      Air conditioning,Multi-function steering wheel
# 5938      Air conditioning,Multi-function steering wheel
# 5940      Air conditioning,Multi-function steering wheel
# 6920                                    Air conditioning
# 6922                                    Air conditioning
# 6927                                    Air conditioning
# 7709                                                 NaN
# 8408   Air conditioning,Cruise control,Electrically h...
# 8584   Air conditioning,Air suspension,Armrest,Automa...
# 10837                                   Air conditioning
# 10838                                   Air conditioning
# 10857                                   Air conditioning
# 13430  Air conditioning,Automatic climate control,Cru...
# 13470  Air conditioning,Multi-function steering wheel...
# 13576  Air conditioning,Automatic climate control,Cru...
# 13703  Air conditioning,Automatic climate control,Cru...
# 13725  Air conditioning,Automatic climate control,Cru...
# 13852                                                NaN
# 13900  Air conditioning,Automatic climate control,Cru...
# 14107                     Air conditioning,Power windows
# 14124  Air conditioning,Automatic climate control,Cru...
# 14127  Air conditioning,Automatic climate control,Cru...
# 14134                       Cruise control,Power windows
# 14135                       Cruise control,Power windows
# 14480  Air conditioning,Cruise control,Electrical sid...
# 14869  Air conditioning,Cruise control,Electrical sid...
# 14870  Air conditioning,Cruise control,Electrical sid...
# 14928                                   Air conditioning
# 14990                                                NaN
# 15058                                   Air conditioning
# 15059                                   Air conditioning
# 15060                                   Air conditioning
# 15124                                                NaN
# 15269                                   Air conditioning
# 15275                                   Air conditioning
# 15289                                                NaN
# 15307                                                NaN
# 15378                                                NaN
# 15437  Air conditioning,Automatic climate control,Cru...
# 15452                                                NaN
# 15456                                                NaN
# 15457                                                NaN
# 15488                                                NaN
# 15489  Air conditioning,Armrest,Automatic climate con...
# 15491  Air conditioning,Armrest,Automatic climate con...
# 15499                                                NaN
# 15544                                                NaN
# 15556                                                NaN
# 15589  Air conditioning,Automatic climate control,Cru...
# 15696  Air conditioning,Automatic climate control,Cru...
# 15712  Air conditioning,Automatic climate control,Cru...
# 15736                                                NaN
# 15770                                                NaN
#
#                                      entertainment&media  \
# 3175   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 3255               Bluetooth,On-board computer,Radio,USB
# 3975   Bluetooth,CD player,Digital radio,MP3,On-board...
# 3997                   Bluetooth,On-board computer,Radio
# 4206                                                 NaN
# 4297                                                 NaN
# 4298                                                 NaN
# 5718                                                 NaN
# 5938                                                 NaN
# 5940                                                 NaN
# 6920                                                 NaN
# 6922                                                 NaN
# 6927                                                 NaN
# 7709                                                 NaN
# 8408   Bluetooth,CD player,Hands-free equipment,On-bo...
# 8584   Bluetooth,CD player,Digital radio,Hands-free e...
# 10837                                                NaN
# 10838                                                NaN
# 10857                                                NaN
# 13430   Bluetooth,Hands-free equipment,On-board computer
# 13470                                                NaN
# 13576   Bluetooth,Hands-free equipment,On-board computer
# 13703   Bluetooth,Hands-free equipment,On-board computer
# 13725   Bluetooth,Hands-free equipment,On-board computer
# 13852                                                NaN
# 13900  Bluetooth,Hands-free equipment,On-board comput...
# 14107                                                NaN
# 14124  Bluetooth,Hands-free equipment,On-board comput...
# 14127  Bluetooth,Hands-free equipment,On-board comput...
# 14134                                  On-board computer
# 14135                                  On-board computer
# 14480  Bluetooth,Hands-free equipment,On-board comput...
# 14869  Bluetooth,Digital radio,Hands-free equipment,O...
# 14870  Bluetooth,Hands-free equipment,On-board comput...
# 14928                                                NaN
# 14990                                                NaN
# 15058                                                NaN
# 15059                                                NaN
# 15060                                                NaN
# 15124                                                NaN
# 15269                                                NaN
# 15275                                                NaN
# 15289                                                NaN
# 15307                                                NaN
# 15378                                                NaN
# 15437                            Digital radio,Radio,USB
# 15452                                                NaN
# 15456                                                NaN
# 15457                                                NaN
# 15488                                                NaN
# 15489  Bluetooth,Digital radio,MP3,On-board computer,...
# 15491  Bluetooth,Digital radio,MP3,On-board computer,...
# 15499                                                NaN
# 15544                                                NaN
# 15556                                                NaN
# 15589                                          Radio,USB
# 15696                            Digital radio,Radio,USB
# 15712                                          Radio,USB
# 15736                                                NaN
# 15770                                                NaN
#
#                                                   extras  \
# 3175   Alloy wheels,Sport package,Trailer hitch,Voice...
# 3255                          Alloy wheels,Shift paddles
# 3975   Alloy wheels,Roof rack,Sport package,Sport sea...
# 3997                                        Alloy wheels
# 4206                                                 NaN
# 4297                                                 NaN
# 4298                                                 NaN
# 5718                                                 NaN
# 5938                                                 NaN
# 5940                                                 NaN
# 6920                                                 NaN
# 6922                                                 NaN
# 6927                                                 NaN
# 7709                                                 NaN
# 8408                            Alloy wheels,Sport seats
# 8584   Alloy wheels,Catalytic Converter,Handicapped e...
# 10837                                                NaN
# 10838                                                NaN
# 10857                                                NaN
# 13430                                      Sport package
# 13470                                                NaN
# 13576                                      Sport package
# 13703                                                NaN
# 13725                                                NaN
# 13852                                                NaN
# 13900                                                NaN
# 14107                                                NaN
# 14124                                      Sport package
# 14127                                      Sport package
# 14134                            Roof rack,Sport package
# 14135                            Roof rack,Sport package
# 14480                                                NaN
# 14869                                                NaN
# 14870                                                NaN
# 14928                                                NaN
# 14990                                                NaN
# 15058                                                NaN
# 15059                                                NaN
# 15060                                                NaN
# 15124                                                NaN
# 15269                                                NaN
# 15275                                                NaN
# 15289                                                NaN
# 15307                                                NaN
# 15378                                                NaN
# 15437                                       Touch screen
# 15452                                                NaN
# 15456                                                NaN
# 15457                                                NaN
# 15488                                                NaN
# 15489            Alloy wheels,Touch screen,Voice Control
# 15491            Alloy wheels,Touch screen,Voice Control
# 15499                                                NaN
# 15544                                                NaN
# 15556                                                NaN
# 15589                                                NaN
# 15696                                       Touch screen
# 15712                                                NaN
# 15736                                                NaN
# 15770                                                NaN
#
#                                          safety&security  gears  \
# 3175   ABS,Adaptive headlights,Central door lock,Cent...    6.0
# 3255   ABS,Alarm system,Central door lock,Driver-side...    7.0
# 3975   ABS,Adaptive headlights,Central door lock with...    7.0
# 3997   ABS,Daytime running lights,Driver-side airbag,...    NaN
# 4206   ABS,Central door lock,Daytime running lights,D...    NaN
# 4297   ABS,Central door lock,Daytime running lights,D...    NaN
# 4298   ABS,Central door lock,Daytime running lights,D...    NaN
# 5718   ABS,Central door lock,Daytime running lights,D...    NaN
# 5938   ABS,Central door lock,Daytime running lights,D...    NaN
# 5940   ABS,Central door lock,Daytime running lights,D...    NaN
# 6920   ABS,Central door lock,Daytime running lights,D...    NaN
# 6922   ABS,Central door lock,Daytime running lights,D...    NaN
# 6927   ABS,Central door lock,Daytime running lights,D...    NaN
# 7709                                                 NaN    NaN
# 8408   ABS,Central door lock,Daytime running lights,D...    5.0
# 8584   ABS,Adaptive Cruise Control,Adaptive headlight...    NaN
# 10837  ABS,Central door lock,Daytime running lights,D...    NaN
# 10838  ABS,Central door lock,Daytime running lights,D...    NaN
# 10857  ABS,Central door lock,Daytime running lights,D...    NaN
# 13430  ABS,Daytime running lights,Driver-side airbag,...    NaN
# 13470  ABS,Central door lock,Daytime running lights,D...    NaN
# 13576  ABS,Daytime running lights,Driver-side airbag,...    NaN
# 13703        ABS,Electronic stability control,Fog lights    NaN
# 13725        ABS,Electronic stability control,Fog lights    NaN
# 13852                                 ABS,Power steering    NaN
# 13900  ABS,Daytime running lights,Driver-side airbag,...    NaN
# 14107  ABS,Central door lock,Daytime running lights,D...    NaN
# 14124  ABS,Daytime running lights,Driver-side airbag,...    NaN
# 14127  ABS,Daytime running lights,Driver-side airbag,...    NaN
# 14134  ABS,Central door lock,Daytime running lights,D...    NaN
# 14135  ABS,Central door lock,Daytime running lights,D...    NaN
# 14480  ABS,Central door lock,Central door lock with r...    5.0
# 14869  ABS,Central door lock,Driver-side airbag,Elect...    5.0
# 14870  ABS,Central door lock,Driver-side airbag,Elect...    5.0
# 14928  ABS,Central door lock,Daytime running lights,D...    NaN
# 14990                                                NaN    7.0
# 15058  ABS,Central door lock,Daytime running lights,D...    NaN
# 15059  ABS,Central door lock,Daytime running lights,D...    NaN
# 15060  ABS,Central door lock,Daytime running lights,D...    NaN
# 15124                                                NaN    6.0
# 15269  ABS,Central door lock,Daytime running lights,D...    NaN
# 15275  ABS,Central door lock,Daytime running lights,D...    NaN
# 15289                                                NaN    6.0
# 15307                                                NaN    6.0
# 15378                                                NaN    6.0
# 15437  ABS,Alarm system,Driver-side airbag,Electronic...    6.0
# 15452                                                NaN    6.0
# 15456                                                NaN    6.0
# 15457                                                NaN    6.0
# 15488                                                NaN    7.0
# 15489  ABS,Adaptive Cruise Control,Blind spot monitor...    6.0
# 15491  ABS,Adaptive Cruise Control,Blind spot monitor...    6.0
# 15499                                                NaN    7.0
# 15544                                                NaN    7.0
# 15556                                                NaN    6.0
# 15589  ABS,Driver-side airbag,Electronic stability co...    6.0
# 15696  ABS,Alarm system,Driver-side airbag,Electronic...    6.0
# 15712  ABS,Driver-side airbag,Electronic stability co...    6.0
# 15736                                                NaN    7.0
# 15770                                                NaN    6.0
#
#       country_version  consumption_comb  consumption_city  \
# 3175              NaN               3.8               4.5
# 3255              NaN               3.8               4.3
# 3975              NaN               4.7               5.6
# 3997              NaN               NaN               NaN
# 4206              NaN               5.1               6.7
# 4297              NaN               5.1               6.7
# 4298              NaN               5.1               6.7
# 5718              NaN               4.5               5.7
# 5938              NaN               4.5               5.7
# 5940              NaN               4.5               5.7
# 6920              NaN               3.7               4.2
# 6922              NaN               3.7               4.2
# 6927              NaN               3.7               4.2
# 7709              NaN               NaN               NaN
# 8408          Germany               NaN               NaN
# 8584              NaN               NaN               NaN
# 10837             NaN               5.6               7.8
# 10838             NaN               5.6               7.8
# 10857             NaN               5.6               7.8
# 13430             NaN               NaN               NaN
# 13470             NaN               NaN               NaN
# 13576             NaN               NaN               NaN
# 13703             NaN               NaN               NaN
# 13725             NaN               NaN               NaN
# 13852             NaN               NaN               NaN
# 13900             NaN               NaN               NaN
# 14107             NaN               3.3               3.5
# 14124             NaN               NaN               NaN
# 14127             NaN               NaN               NaN
# 14134             NaN               NaN               NaN
# 14135             NaN               NaN               NaN
# 14480             NaN               5.6               7.2
# 14869             NaN               NaN               6.4
# 14870             NaN               NaN               6.4
# 14928             NaN               4.6               NaN
# 14990             NaN               6.8               8.7
# 15058             NaN               4.6               NaN
# 15059             NaN               4.6               NaN
# 15060             NaN               4.6               NaN
# 15124             NaN               4.6               NaN
# 15269             NaN               4.6               NaN
# 15275             NaN               4.6               NaN
# 15289             NaN               4.4               5.1
# 15307             NaN               4.4               5.1
# 15378             NaN               4.4               5.1
# 15437             NaN               4.7               5.1
# 15452             NaN               4.6               NaN
# 15456             NaN               4.6               NaN
# 15457             NaN               4.6               NaN
# 15488             NaN               NaN               NaN
# 15489             NaN               4.6               NaN
# 15491             NaN               4.6               NaN
# 15499             NaN               NaN               NaN
# 15544             NaN               NaN               NaN
# 15556             NaN               4.6               NaN
# 15589             NaN               4.7               5.1
# 15696             NaN               4.7               5.1
# 15712             NaN               4.7               5.1
# 15736             NaN               NaN               NaN
# 15770             NaN               4.6               NaN
#
#        consumption_country  age
# 3175                   3.4  3.0
# 3255                   3.5  3.0
# 3975                   4.2  2.0
# 3997                   NaN  2.0
# 4206                   4.1  2.0
# 4297                   4.1  2.0
# 4298                   4.1  2.0
# 5718                   3.8  3.0
# 5938                   3.8  3.0
# 5940                   3.8  3.0
# 6920                   3.3  2.0
# 6922                   3.3  2.0
# 6927                   3.3  2.0
# 7709                   NaN  0.0
# 8408                   NaN  1.0
# 8584                   NaN  2.0
# 10837                  4.2  2.0
# 10838                  4.2  2.0
# 10857                  4.2  2.0
# 13430                  NaN  3.0
# 13470                  NaN  1.0
# 13576                  NaN  3.0
# 13703                  NaN  2.0
# 13725                  NaN  2.0
# 13852                  NaN  2.0
# 13900                  NaN  2.0
# 14107                  3.1  2.0
# 14124                  NaN  1.0
# 14127                  NaN  1.0
# 14134                  NaN  1.0
# 14135                  NaN  1.0
# 14480                  4.7  1.0
# 14869                  4.2  NaN
# 14870                  4.2  NaN
# 14928                  4.4  3.0
# 14990                  5.6  1.0
# 15058                  4.4  2.0
# 15059                  4.4  2.0
# 15060                  4.4  2.0
# 15124                  4.4  3.0
# 15269                  4.4  3.0
# 15275                  4.4  3.0
# 15289                  NaN  NaN
# 15307                  NaN  NaN
# 15378                  NaN  NaN
# 15437                  4.4  1.0
# 15452                  4.4  NaN
# 15456                  4.4  1.0
# 15457                  4.4  1.0
# 15488                  NaN  NaN
# 15489                  4.4  1.0
# 15491                  4.4  1.0
# 15499                  NaN  NaN
# 15544                  NaN  NaN
# 15556                  4.4  NaN
# 15589                  4.4  1.0
# 15696                  4.4  0.0
# 15712                  4.4  0.0
# 15736                  NaN  NaN
# 15770                  4.4  NaN

# %%
df.groupby(["make", "model"])["body_type"].value_counts(dropna=False)
# Out:
# make     model     body_type
# Audi     A1        Sedans           1538
#                    Compact          1039
#                    Station wagon      21
#                    Other              13
#                    Coupe               2
#                    Van                 1
#          A2        Off-Road            1
#          A3        Sedans           2598
#                    Station wagon     282
#                    Compact           182
#                    Other              16
#                    Convertible         8
#                    NaN                 7
#                    Coupe               4
# Opel     Astra     Station wagon    1211
#                    Sedans           1053
#                    Compact           185
#                    Other              67
#                    NaN                 7
#                    Coupe               2
#                    Off-Road            1
#          Corsa     Compact          1230
#                    Sedans            875
#                    Other              87
#                    Coupe              13
#                    Transporter         7
#                    Off-Road            3
#                    NaN                 2
#                    Van                 2
#          Insignia  Station wagon    1611
#                    Sedans            900
#                    Other              48
#                    Compact            27
#                    Off-Road            7
#                    NaN                 3
#                    Coupe               1
#                    Van                 1
# Renault  Clio      Sedans            918
#                    Compact           484
#                    Station wagon     337
#                    Other              51
#                    Transporter        29
#                    NaN                15
#                    Off-Road            2
#                    Van                 2
#                    Coupe               1
#          Duster    Off-Road           34
#          Espace    Van               777
#                    Station wagon      91
#                    Transporter        52
#                    NaN                26
#                    Sedans             21
#                    Off-Road            8
#                    Other               8
#                    Compact             6
#                    Coupe               2
# Name: body_type, dtype: int64

# %%
df.groupby(["make", "model", "nr_of_doors"])["body_type"].value_counts(dropna=False)
# Out:
# make     model   nr_of_doors  body_type
# Audi     A1      2.0          Compact       69
#                               Sedans        29
#                               Coupe          1
#                  3.0          Sedans       130
#                               Compact       80
#                                           ...
# Renault  Espace  5.0          Other          7
#                               Off-Road       6
#                               Compact        5
#                               Coupe          1
#                  7.0          Van            1
# Name: body_type, Length: 111, dtype: int64

# %%
#df.groupby(["make", "model"])["body_type"].describe(include="object")["top"]
df.groupby(["make", "model"])["body_type"].apply(lambda x: x.mode()[0])
# Out:
# make     model
# Audi     A1                 Sedans
#          A2               Off-Road
#          A3                 Sedans
# Opel     Astra       Station wagon
#          Corsa             Compact
#          Insignia    Station wagon
# Renault  Clio               Sedans
#          Duster           Off-Road
#          Espace                Van
# Name: body_type, dtype: object

# %%
df.body_type = df.groupby(["make", "model"])["body_type"].apply(lambda x: x.fillna(x.mode()[0]))

# %%
df.body_type.value_counts()
# Out:
# Sedans           7925
# Station wagon    3563
# Compact          3155
# Van               809
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.shape
# Out:
# (15919, 35)

# %% [markdown]
# ## vat

# %%
check_df("vat")
# Out:
# column name :  vat
# --------------------------------
# Per_of_Nulls   :  % 28.35
# Num_of_Nulls   :  4513
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
# ******************************

# %%
df.groupby("vat").describe(include="O")
# Out:
#                  body_type                        type                     \
#                      count unique     top  freq  count unique   top  freq
# vat
# Price negotiable       426      9  Sedans   286    426      3  Used   421
# VAT deductible       10980      9  Sedans  5248  10980      5  Used  6787
#
#                    make                     model                  body_color  \
#                   count unique   top  freq  count unique top  freq      count
# vat
# Price negotiable    426      3  Audi   182    426      7  A3   101        426
# VAT deductible    10980      3  Opel  5415  10980      9  A3  2209      10586
#
#                                      paint_type                         \
#                  unique    top  freq      count unique       top  freq
# vat
# Price negotiable     10  Black   109        245      1  Metallic   245
# VAT deductible       13  Black  2704       7558      3  Metallic  7312
#
#                  body_color_original                                         \
#                                count unique                        top freq
# vat
# Price negotiable                  17     17  Floretzilver (grijs metal    1
# VAT deductible                  9543   1568               Onyx Schwarz  314
#
#                  upholstery                     gearing_type                 \
#                       count unique    top  freq        count unique     top
# vat
# Price negotiable        134      4  Cloth    82          426      3  Manual
# VAT deductible         9780      6  Cloth  7404        10980      3  Manual
#
#                        drive_chain                       fuel                  \
#                   freq       count unique    top  freq  count unique      top
# vat
# Price negotiable   204          95      2  front    92    426      4   Diesel
# VAT deductible    5502        6876      2  front  6762  10980      4  Benzine
#
#                        emission_class                       \
#                   freq          count unique     top  freq
# vat
# Price negotiable   223            401      6  Euro 6   361
# VAT deductible    6183           8801      6  Euro 6  6915
#
#                  comfort&convenience         \
#                                count unique
# vat
# Price negotiable                 423    333
# VAT deductible                 10811   4368
#
#                                                                           \
#                                                                 top freq
# vat
# Price negotiable  Air conditioning,Seat ventilation,Split rear s...   15
# VAT deductible    Air conditioning,Electrical side mirrors,Hill ...  163
#
#                  entertainment&media         \
#                                count unique
# vat
# Price negotiable                 414    100
# VAT deductible                 10609    300
#
#                                                                            \
#                                                                 top  freq
# vat
# Price negotiable  Bluetooth,CD player,Hands-free equipment,MP3,O...    32
# VAT deductible    Bluetooth,Hands-free equipment,On-board comput...  1088
#
#                  extras                            safety&security         \
#                   count unique           top  freq           count unique
# vat
# Price negotiable    372    139  Alloy wheels    71             422    298
# VAT deductible     9471    498  Alloy wheels  2092           10782   2973
#
#                                                                           \
#                                                                 top freq
# vat
# Price negotiable  ABS,Adaptive Cruise Control,Alarm system,Centr...   12
# VAT deductible    ABS,Central door lock,Daytime running lights,D...  461
#
#                  country_version
#                            count unique      top  freq
# vat
# Price negotiable              43      6    Italy    14
# VAT deductible              5966     20  Germany  3812

# %%
df.vat.value_counts().index
# Out:
# Index(['VAT deductible', 'Price negotiable'], dtype='object')

# %%
df.vat = df.vat.fillna(method="bfill")

# %%
df.vat.value_counts(dropna=False)
# Out:
# VAT deductible      15083
# Price negotiable      836
# Name: vat, dtype: int64

# %% [markdown]
# ## type

# %%
df.type.mode()
# Out:
# 0    Used
# dtype: object

# %%
# there are onşy 2 missing value in this column so we will fill these values with ffill method
df.type = df.type.fillna(method="ffill")

# %%
df.type.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## age

# %%
df.age.isnull().sum()
# Out:
# 1597

# %%
df.groupby("type").age.median()
# Out:
# type
# Demonstration     0.0
# Employee's car    1.0
# New               0.0
# Pre-registered    0.0
# Used              2.0
# Name: age, dtype: float64

# %%
df["age"] = df.groupby("type").age.apply(lambda x: x.fillna(x.median()))

# %%
df.age.value_counts()
# Out:
# 1.0    4525
# 0.0    4412
# 3.0    3674
# 2.0    3308
# Name: age, dtype: int64

# %%
df.age. isnull().sum()
# Out:
# 0

# %% [markdown]
# ## km

# %%
check_df("km")
# Out:
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 6.43
# Num_of_Nulls   :  1024
# 10.0       1045
# NaN        1024
# 1.0         367
# 5.0         170
# 50.0        148
#            ...
# 67469.0       1
# 43197.0       1
# 10027.0       1
# 35882.0       1
# 57.0          1
# Name: km, Length: 6690, dtype: int64
# ******************************

# %%
df.groupby(["type","age"])["km"].mean()
# Out:
# type            age
# Demonstration   0.0     3373.867550
#                 1.0     8294.200000
#                 2.0    25327.296296
#                 3.0    45500.000000
# Employee's car  0.0     4473.933884
#                 1.0    19295.278068
#                 2.0    37926.505051
#                 3.0    59123.647059
# New             0.0       16.987484
#                 1.0       53.500000
# Pre-registered  0.0      100.648820
#                 1.0      435.514925
#                 2.0     1854.000000
#                 3.0       10.000000
# Used            0.0     3712.170610
#                 1.0    18807.503474
#                 2.0    41887.937559
#                 3.0    77566.423098
# Name: km, dtype: float64

# %%
df.km = df.groupby(["type","age"])["km"].apply(lambda x: x.fillna(x.mean()))

# %%
df.km.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## prev_owner and previous_owners

# %%
check_df("prev_owner")
# Out:
# column name :  prev_owner
# --------------------------------
# Per_of_Nulls   :  % 42.89
# Num_of_Nulls   :  6828
# 1.0    8294
# NaN    6828
# 2.0     778
# 3.0      17
# 4.0       2
# Name: prev_owner, dtype: int64
# ******************************

# %%
check_df("previous_owners")
# Out:
# column name :  previous_owners
# --------------------------------
# Per_of_Nulls   :  % 41.71
# Num_of_Nulls   :  6640
# 1.0    8294
# NaN    6640
# 2.0     778
# 0.0     188
# 3.0      17
# 4.0       2
# Name: previous_owners, dtype: int64
# ******************************

# %%
df.groupby("previous_owners")["prev_owner"].value_counts(dropna=False)
# Out:
# previous_owners  prev_owner
# 0.0              NaN            188
# 1.0              1.0           8294
# 2.0              2.0            778
# 3.0              3.0             17
# 4.0              4.0              2
# Name: prev_owner, dtype: int64

# %%
# as we see prev_owner and previous_owners columns are the same 
df.drop(columns="prev_owner", inplace=True)

# %%
df.groupby("age")["previous_owners"].apply(lambda x: x.fillna(x.mode()[0])).value_counts()
# Out:
# 1.0    14934
# 2.0      778
# 0.0      188
# 3.0       17
# 4.0        2
# Name: previous_owners, dtype: int64

# %%
df.groupby("type")["previous_owners"].apply(lambda x: x.fillna(x.mode()[0])).value_counts()
# Out:
# 1.0    13463
# 0.0     1659
# 2.0      778
# 3.0       17
# 4.0        2
# Name: previous_owners, dtype: int64

# %%
df.previous_owners = df.groupby("type")["previous_owners"].apply(lambda x: x.fillna(x.mode()[0]))

# %%
df.previous_owners.isnull().sum()
# Out:
# 0

# %%
df.previous_owners.value_counts(dropna=False)
# Out:
# 1.0    13463
# 0.0     1659
# 2.0      778
# 3.0       17
# 4.0        2
# Name: previous_owners, dtype: int64

# %% [markdown]
# ## hp_kW

# %%
check_df("hp_kW")
# Out:
# column name :  hp_kW
# --------------------------------
# Per_of_Nulls   :  % 0.55
# Num_of_Nulls   :  88
# 85.0     2542
# 66.0     2122
# 81.0     1402
# 100.0    1308
# 110.0    1112
#          ...
# 84.0        1
# 195.0       1
# 44.0        1
# 239.0       1
# 9.0         1
# Name: hp_kW, Length: 81, dtype: int64
# ******************************

# %%
df.groupby(["make", "model","body_type"])["hp_kW"].median()
# Out:
# make     model     body_type
# Audi     A1        Compact           70.0
#                    Coupe             77.5
#                    Other             70.0
#                    Sedans            70.0
#                    Station wagon     70.0
#                    Van              147.0
#          A2        Off-Road          85.0
#          A3        Compact           85.0
#                    Convertible      110.0
#                    Coupe             81.0
#                    Other             85.0
#                    Sedans            85.0
#                    Station wagon     85.0
# Opel     Astra     Compact           81.0
#                    Coupe            106.5
#                    Off-Road         110.0
#                    Other             81.0
#                    Sedans            81.0
#                    Station wagon    100.0
#          Corsa     Compact           66.0
#                    Coupe             55.0
#                    Off-Road          66.0
#                    Other             66.0
#                    Sedans            55.0
#                    Transporter       55.0
#                    Van               51.0
#          Insignia  Compact          121.0
#                    Coupe             81.0
#                    Off-Road         125.0
#                    Other            100.0
#                    Sedans           103.0
#                    Station wagon    121.0
#                    Van              121.0
# Renault  Clio      Compact           56.0
#                    Coupe            147.0
#                    Off-Road          71.0
#                    Other             56.0
#                    Sedans            56.0
#                    Station wagon     66.0
#                    Transporter       56.0
#                    Van               55.0
#          Duster    Off-Road          77.0
#          Espace    Compact          133.0
#                    Coupe            141.5
#                    Off-Road         118.0
#                    Other            118.0
#                    Sedans           118.0
#                    Station wagon    118.0
#                    Transporter      118.0
#                    Van              118.0
# Name: hp_kW, dtype: float64

# %%
df.hp_kW = df.groupby(["make", "model","body_type"])["hp_kW"].apply(lambda x : x.fillna(x.median()))

# %% [markdown]
# ## warranty

# %%
check_df("warranty")
# Out:
# column name :  warranty
# --------------------------------
# Per_of_Nulls   :  % 69.51
# Num_of_Nulls   :  11066
# NaN     11066
# 12.0     2594
# 24.0     1118
# 60.0      401
# 36.0      279
# 48.0      149
# 6.0       125
# 72.0       59
# 3.0        33
# 23.0       11
# 18.0       10
# 20.0        7
# 25.0        6
# 2.0         5
# 50.0        4
# 26.0        4
# 16.0        4
# 4.0         3
# 1.0         3
# 19.0        3
# 34.0        3
# 13.0        3
# 28.0        2
# 22.0        2
# 14.0        2
# 11.0        2
# 46.0        2
# 21.0        2
# 9.0         2
# 17.0        2
# 45.0        2
# 33.0        1
# 40.0        1
# 65.0        1
# 10.0        1
# 15.0        1
# 7.0         1
# 8.0         1
# 56.0        1
# 49.0        1
# 47.0        1
# 30.0        1
# Name: warranty, dtype: int64
# ******************************

# %%
df.groupby(["make", "model","age"])["warranty"].mean()
# Out:
# make     model     age
# Audi     A1        0.0    27.970874
#                    1.0    26.300429
#                    2.0    17.679389
#                    3.0    13.926174
#          A2        1.0          NaN
#          A3        0.0    27.697211
#                    1.0    21.706897
#                    2.0    16.654709
#                    3.0    17.111511
# Opel     Astra     0.0    37.803571
#                    1.0    25.795455
#                    2.0    14.987952
#                    3.0    24.797468
#          Corsa     0.0    27.472393
#                    1.0    17.355140
#                    2.0    22.230769
#                    3.0    27.060811
#          Insignia  0.0    31.862637
#                    1.0    25.347826
#                    2.0    17.057971
#                    3.0    15.225434
# Renault  Clio      0.0    35.510204
#                    1.0    15.686441
#                    2.0    16.733333
#                    3.0    10.864198
#          Duster    0.0    12.000000
#          Espace    0.0    37.226415
#                    1.0    22.523810
#                    2.0    15.921875
#                    3.0    12.482014
# Name: warranty, dtype: float64

# %%
df.groupby(["make", "model","age"])["warranty"].median()
# Out:
# make     model     age
# Audi     A1        0.0    24.0
#                    1.0    24.0
#                    2.0    12.0
#                    3.0    12.0
#          A2        1.0     NaN
#          A3        0.0    24.0
#                    1.0    24.0
#                    2.0    12.0
#                    3.0    12.0
# Opel     Astra     0.0    24.0
#                    1.0    12.0
#                    2.0    12.0
#                    3.0    12.0
#          Corsa     0.0    24.0
#                    1.0    12.0
#                    2.0    12.0
#                    3.0    12.0
#          Insignia  0.0    24.0
#                    1.0    12.0
#                    2.0    12.0
#                    3.0    12.0
# Renault  Clio      0.0    24.0
#                    1.0    12.0
#                    2.0    12.0
#                    3.0    12.0
#          Duster    0.0    12.0
#          Espace    0.0    36.0
#                    1.0    22.0
#                    2.0    12.0
#                    3.0    12.0
# Name: warranty, dtype: float64

# %%
# df[df.type == "Used"]["warranty"].replace(np.nan, 0, inplace=True)
# df[df.type == "Used"]["warranty"].fillna(0)

# %%
df.groupby(["type", "age"])["warranty"].value_counts(dropna=False)
# Out:
# type           age  warranty
# Demonstration  0.0  NaN         482
#                     24.0         46
#                     48.0         27
#                     12.0         23
#                     60.0         22
#                                ...
# Used           3.0  21.0          1
#                     23.0          1
#                     26.0          1
#                     40.0          1
#                     48.0          1
# Name: warranty, Length: 152, dtype: int64

# %%
df["warranty"].value_counts(dropna=False)
# Out:
# NaN     11066
# 12.0     2594
# 24.0     1118
# 60.0      401
# 36.0      279
# 48.0      149
# 6.0       125
# 72.0       59
# 3.0        33
# 23.0       11
# 18.0       10
# 20.0        7
# 25.0        6
# 2.0         5
# 50.0        4
# 26.0        4
# 16.0        4
# 4.0         3
# 1.0         3
# 19.0        3
# 34.0        3
# 13.0        3
# 28.0        2
# 22.0        2
# 14.0        2
# 11.0        2
# 46.0        2
# 21.0        2
# 9.0         2
# 17.0        2
# 45.0        2
# 33.0        1
# 40.0        1
# 65.0        1
# 10.0        1
# 15.0        1
# 7.0         1
# 8.0         1
# 56.0        1
# 49.0        1
# 47.0        1
# 30.0        1
# Name: warranty, dtype: int64

# %%
df["warranty"] = df["warranty"].replace(to_replace=np.nan, value=0).astype("float")

# %%
df.loc[df["warranty"] != 0, "warranty"] = 1

# %%
df["warranty"].value_counts(dropna=False)
# Out:
# 0.0    11066
# 1.0     4853
# Name: warranty, dtype: int64

# %% [markdown]
# ## make and model

# %%
check_df("make")
# Out:
# column name :  make
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Opel       7343
# Audi       5712
# Renault    2864
# Name: make, dtype: int64
# ******************************

# %%
check_df("model")
# Out:
# column name :  model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: model, dtype: int64
# ******************************

# %%
# There is no null values in make and model columns

# %% [markdown]
# ## body_color  and body_color_original

# %%
check_df("body_color")
# Out:
# column name :  body_color
# --------------------------------
# Per_of_Nulls   :  % 3.75
# Num_of_Nulls   :  597
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
# ******************************

# %%
check_df("body_color_original")
# Out:
# column name :  body_color_original
# --------------------------------
# Per_of_Nulls   :  % 23.71
# Num_of_Nulls   :  3774
# NaN                              3774
# Onyx Schwarz                      338
# Bianco                            282
# Mythosschwarz Metallic            238
# Brillantschwarz                   216
#                                  ...
# Rouge-Braun (G0Y)                   1
# VARI COLRI DISPONIBILI              1
# Kokosnussbraun Metallic             1
# Farbe frei wählbar                  1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1927, dtype: int64
# ******************************

# %%
df[df.body_color.isnull()]["body_color_original"].value_counts()
# Out:
# wählbar - ggf. mit Aufpreis       118
# wählbar                            88
# Metallic o. Uni (wählbar)          33
# wählbar - ggf gegen Aufpreis       25
# Other                              14
#                                  ...
# rouge eclat                         1
# quarzgrau dunkel Grau metallic      1
# Licht Grau M2                       1
# graphitgrau Metallik                1
# Farbe: Sonstige                     1
# Name: body_color_original, Length: 85, dtype: int64

# %%
df.body_color = df.body_color.fillna(method="bfill")

# %%
df.body_color.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## paint_type

# %%
check_df("paint_type")
# Out:
# column name :  paint_type
# --------------------------------
# Per_of_Nulls   :  % 36.26
# Num_of_Nulls   :  5772
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64
# ******************************

# %%
df.groupby("paint_type")["body_color_original"].value_counts()
# Out:
# paint_type  body_color_original
# Metallic    Onyx Schwarz                 290
#             Mythosschwarz Metallic       225
#             Quarz Grau                   192
#             Gris                         137
#             Nero                         115
#                                         ...
# Uni/basic   VERDE MARE PASTELLO (LT3)      1
#             WEISS 'NACRE'                  1
#             Weiss                          1
#             bleu                           1
#             grigio monsone                 1
# Name: body_color_original, Length: 1571, dtype: int64

# %%
df[df.paint_type.isnull()]["body_color_original"].value_counts()
# Out:
# Brillantschwarz                179
# Bianco                         163
# wählbar - ggf. mit Aufpreis    118
# Blanco                         110
# Grigio                          91
#                               ...
# schnee-weiss                     1
# schneeweiß/schwarz               1
# rouge eclat                      1
# Gris Cosmique                    1
# Cosmos Blau Met                  1
# Name: body_color_original, Length: 623, dtype: int64

# %%
df["paint_type"] = df["paint_type"].fillna(method="ffill")

# %%
df.paint_type.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## body_color_original

# %%
# Since this column contains irrelevant info and its languages is foreign language, we've dropped this column.

# %%
df.drop(columns="body_color_original", inplace=True)

# %% [markdown]
# ## upholstery

# %%
check_df("upholstery")
# Out:
# column name :  upholstery
# --------------------------------
# Per_of_Nulls   :  % 23.37
# Num_of_Nulls   :  3720
# Cloth           9206
# NaN             3720
# Part leather    1499
# Full leather    1009
# Other            368
# Velour            60
# alcantara         57
# Name: upholstery, dtype: int64
# ******************************

# %%
df.extras.value_counts().head(50)
# Out:
# Alloy wheels                                                                                        3245
# Alloy wheels,Touch screen                                                                            697
# Alloy wheels,Voice Control                                                                           577
# Alloy wheels,Touch screen,Voice Control                                                              541
# Alloy wheels,Roof rack                                                                               385
# Alloy wheels,Sport seats                                                                             380
# Roof rack                                                                                            337
# Alloy wheels,Catalytic Converter                                                                     271
# Alloy wheels,Sport seats,Sport suspension                                                            234
# Alloy wheels,Catalytic Converter,Touch screen                                                        228
# Alloy wheels,Sport seats,Voice Control                                                               226
# Catalytic Converter                                                                                  224
# Alloy wheels,Catalytic Converter,Voice Control                                                       203
# Alloy wheels,Roof rack,Touch screen,Voice Control                                                    192
# Alloy wheels,Sport suspension                                                                        177
# Touch screen                                                                                         169
# Alloy wheels,Roof rack,Touch screen                                                                  164
# Alloy wheels,Catalytic Converter,Touch screen,Voice Control                                          132
# Alloy wheels,Sport package                                                                           113
# Alloy wheels,Trailer hitch                                                                           112
# Alloy wheels,Sport suspension,Voice Control                                                          110
# Touch screen,Voice Control                                                                           104
# Alloy wheels,Sport seats,Touch screen                                                                 98
# Alloy wheels,Sport package,Sport seats,Sport suspension                                               94
# Alloy wheels,Roof rack,Sport seats                                                                    93
# Alloy wheels,Sport seats,Touch screen,Voice Control                                                   91
# Alloy wheels,Roof rack,Sport seats,Touch screen,Voice Control                                         87
# Voice Control                                                                                         85
# Alloy wheels,Sport package,Sport seats                                                                81
# Alloy wheels,Sport package,Sport seats,Sport suspension,Voice Control                                 68
# Alloy wheels,Catalytic Converter,Sport seats,Voice Control                                            67
# Alloy wheels,Cab or rented Car,Sport seats,Voice Control                                              62
# Alloy wheels,Roof rack,Voice Control                                                                  60
# Alloy wheels,Sport seats,Sport suspension,Voice Control                                               57
# Alloy wheels,Catalytic Converter,Roof rack,Touch screen,Voice Control                                 57
# Catalytic Converter,Touch screen                                                                      55
# Alloy wheels,Catalytic Converter,Roof rack,Touch screen                                               53
# Roof rack,Touch screen                                                                                52
# Alloy wheels,Roof rack,Ski bag,Sport seats,Touch screen,Voice Control                                 50
# Roof rack,Touch screen,Voice Control                                                                  49
# Alloy wheels,Roof rack,Trailer hitch                                                                  47
# Alloy wheels,Shift paddles,Sport package,Sport seats,Sport suspension,Touch screen,Voice Control      46
# Alloy wheels,Shift paddles                                                                            45
# Alloy wheels,Roof rack,Sport seats,Touch screen                                                       38
# Alloy wheels,Sport package,Sport seats,Voice Control                                                  38
# Cab or rented Car                                                                                     37
# Alloy wheels,Catalytic Converter,Sport seats,Sport suspension,Voice Control                           34
# Catalytic Converter,Touch screen,Voice Control                                                        34
# Alloy wheels,Catalytic Converter,Sport package,Sport seats,Sport suspension,Voice Control             33
# Roof rack,Voice Control                                                                               33
# Name: extras, dtype: int64

# %%
get_diff_category_column(df["comfort&convenience"])
# Out:
# {0: 'Air conditioning',
#  1: 'Air suspensio',
#  2: 'Armrest',
#  3: 'Automatic climate control',
#  4: 'Auxiliary heating',
#  5: 'Cruise control',
#  6: 'Electric Starter',
#  7: 'Electric tailgate',
#  8: 'Electrical side mirrors',
#  9: 'Electrically adjustable seats',
#  10: 'Electrically heated windshield',
#  11: 'Heads-up display',
#  12: 'Heated steering wheel',
#  13: 'Hill Holder',
#  14: 'Keyless central door lock',
#  15: 'Leather seats',
#  16: 'Leather steering wheel',
#  17: 'Light sensor',
#  18: 'Lumbar support',
#  19: 'Massage seats',
#  20: 'Multi-function steering wheel',
#  21: 'Navigation system',
#  22: 'Panorama roof',
#  23: 'Park Distance Control',
#  24: 'Parking assist system camera',
#  25: 'Parking assist system self-steering',
#  26: 'Parking assist system sensors front',
#  27: 'Parking assist system sensors rear',
#  28: 'Power windows',
#  29: 'Rain sensor',
#  30: 'Seat heating',
#  31: 'Seat ventilatio',
#  32: 'Split rear seats',
#  33: 'Start-stop system',
#  34: 'Sunroof',
#  35: 'Tinted windows',
#  36: 'Wind deflector',
#  37: 'Windshield'}

# %%
df["comfort&convenience"].str.contains("Leather seats").value_counts()
# Out:
# False    14951
# True        48
# Name: comfort&convenience, dtype: int64

# %%
df[df.upholstery.isnull()]["comfort&convenience"].str.contains("Leather seats").value_counts(dropna=False)
# Out:
# False    2939
# NaN       779
# True        2
# Name: comfort&convenience, dtype: int64

# %%
df.groupby(["make", "model", "price_€"])["upholstery"].fillna(method="pad").fillna(method="backfill").value_counts(dropna=False, normalize=True)
# Out:
# Cloth           0.748288
# Part leather    0.124003
# Full leather    0.085181
# Other           0.031849
# Velour          0.006031
# alcantara       0.004649
# Name: upholstery, dtype: float64

# %%
df.upholstery = df.groupby(["make", "model", "price_€"])["upholstery"].fillna(method="pad").fillna(method="backfill")

# %%
# As the second option we can create an additional column according to "price_€" column("high", "medium", "low" price).
# We can fill NaN values of upholstery column by grouping this new column.

# %% [markdown]
# ## nr_of_doors

# %%
check_df("nr_of_doors")
# Out:
# column name :  nr_of_doors
# --------------------------------
# Per_of_Nulls   :  % 1.33
# Num_of_Nulls   :  212
# 5.0    11575
# 4.0     3079
# 3.0      832
# 2.0      219
# NaN      212
# 1.0        1
# 7.0        1
# Name: nr_of_doors, dtype: int64
# ******************************

# %%
df[(df.make == "Opel")&(df.model == "Corsa")&(df.body_type == "Van")]["nr_of_doors"].fillna(5, inplace=True)

# %%
df.groupby(["make", "model", "body_type"])["nr_of_doors"].value_counts(dropna = False)
# Out:
# make     model   body_type    nr_of_doors
# Audi     A1      Compact      5.0            666
#                               4.0            207
#                               3.0             80
#                               2.0             69
#                               NaN             17
#                                             ...
# Renault  Espace  Transporter  5.0             52
#                  Van          5.0            704
#                               4.0             90
#                               NaN              8
#                               7.0              1
# Name: nr_of_doors, Length: 129, dtype: int64

# %%
df.nr_of_doors = df.groupby(["make","model", "body_type"])['nr_of_doors'].apply(lambda x: x.fillna(x.mode()[0] if any(x.mode()) else df['nr_of_doors'].mode()[0]))

# %%
df.nr_of_doors.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## nr_of_seats

# %%
check_df("nr_of_seats")
# Out:
# column name :  nr_of_seats
# --------------------------------
# Per_of_Nulls   :  % 6.14
# Num_of_Nulls   :  977
# 5.0    13336
# 4.0     1125
# NaN      977
# 7.0      362
# 2.0      116
# 6.0        2
# 3.0        1
# Name: nr_of_seats, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "body_type"])["nr_of_seats"].value_counts(dropna = False)
# Out:
# make     model   body_type    nr_of_seats
# Audi     A1      Compact      5.0            538
#                               4.0            431
#                               NaN             68
#                               3.0              1
#                               6.0              1
#                                             ...
# Renault  Espace  Transporter  NaN              1
#                  Van          5.0            383
#                               7.0            315
#                               NaN            104
#                               4.0              1
# Name: nr_of_seats, Length: 116, dtype: int64

# %%
df.nr_of_seats = df.groupby(["make","model", "body_type"])['nr_of_seats'].apply(lambda x: x.fillna(x.mode()[0] if any(x.mode()) else df['nr_of_seats'].mode()[0]))

# %%
df.nr_of_seats.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## gearing_type

# %%
check_df("gearing_type")
# Out:
# column name :  gearing_type
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# ******************************

# %%
# There is no null value to fill

# %% [markdown]
# ## cylinders

# %%
check_df("cylinders")
# Out:
# column name :  cylinders
# --------------------------------
# Per_of_Nulls   :  % 35.68
# Num_of_Nulls   :  5680
# 4.0    8105
# NaN    5680
# 3.0    2104
# 5.0      22
# 6.0       3
# 8.0       2
# 2.0       2
# 1.0       1
# Name: cylinders, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "hp_kW"])["cylinders"].apply(lambda x: x.fillna(x.mode()[0] if any(x.mode()) else df["cylinders"].mode()[0])).value_counts(dropna=False)
# Out:
# 4.0    12559
# 3.0     3325
# 5.0       22
# 8.0        7
# 6.0        3
# 2.0        2
# 1.0        1
# Name: cylinders, dtype: int64

# %%
df["cylinders"] = df.groupby(["make", "model", "hp_kW"])["cylinders"].apply(lambda x: x.fillna(x.mode()[0] if any(x.mode()) else df["cylinders"].mode()[0]))

# %%
df.cylinders.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## engine_displacement_cc

# %%
check_df("engine_displacement_cc")
# Out:
# column name :  engine_displacement_cc
# --------------------------------
# Per_of_Nulls   :  % 3.12
# Num_of_Nulls   :  496
# 1598.0    4761
# 999.0     2438
# 1398.0    1314
# 1399.0     749
# 1229.0     677
#           ...
# 122.0        1
# 1198.0       1
# 1195.0       1
# 2967.0       1
# 1800.0       1
# Name: engine_displacement_cc, Length: 78, dtype: int64
# ******************************

# %%
df["engine_displacement_cc"] = df.groupby(["make","model", "cylinders", "hp_kW"])["engine_displacement_cc"].apply(lambda x : x.fillna(x.mode()[0] if any(x.mode()) else df.engine_displacement_cc.mode()[0]))

# %%
df.engine_displacement_cc.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## weight_kg

# %%
check_df("weight_kg")
# Out:
# column name :  weight_kg
# --------------------------------
# Per_of_Nulls   :  % 43.81
# Num_of_Nulls   :  6974
# NaN       6974
# 1163.0     574
# 1360.0     356
# 1165.0     301
# 1335.0     242
#           ...
# 1960.0       1
# 1258.0       1
# 1167.0       1
# 1331.0       1
# 2037.0       1
# Name: weight_kg, Length: 435, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "body_type"])["weight_kg"].value_counts(dropna=False).head(60)
# Out:
# make  model  body_type  weight_kg
# Audi  A1     Compact    NaN          526
#                         1180.0        86
#                         1165.0        77
#                         1200.0        65
#                         1135.0        53
#                         1195.0        40
#                         1065.0        36
#                         1110.0        22
#                         1250.0        17
#                         1105.0        12
#                         1090.0         9
#                         1215.0         9
#                         1240.0         7
#                         1035.0         6
#                         1134.0         6
#                         1155.0         5
#                         1205.0         5
#                         1275.0         5
#                         1485.0         5
#                         1225.0         4
#                         1600.0         4
#                         1115.0         3
#                         1133.0         3
#                         1230.0         3
#                         1285.0         3
#                         1335.0         3
#                         1345.0         3
#                         1010.0         2
#                         1040.0         2
#                         1100.0         2
#                         1220.0         2
#                         1235.0         2
#                         102.0          1
#                         1125.0         1
#                         1138.0         1
#                         1140.0         1
#                         1147.0         1
#                         1150.0         1
#                         1280.0         1
#                         1500.0         1
#                         1580.0         1
#                         1625.0         1
#                         1675.0         1
#                         1792.0         1
#              Coupe      NaN            1
#                         1010.0         1
#              Other      NaN            9
#                         1165.0         1
#                         1205.0         1
#                         1230.0         1
#                         1250.0         1
#              Sedans     NaN          613
#                         1135.0       106
#                         1165.0        89
#                         1250.0        58
#                         1110.0        53
#                         1180.0        51
#                         1275.0        51
#                         1230.0        50
#                         1195.0        45
# Name: weight_kg, dtype: int64

# %%
df.groupby(["make", "model", "body_type"])["weight_kg"].apply(lambda x : x.fillna(x.mean())).value_counts(dropna=False).head(100)
# Out:
# 1395.619545    978
# 1627.555267    845
# 1174.057087    724
# 1403.741611    622
# 1259.656216    613
#               ...
# 1215.000000     29
# 1633.000000     29
# 1322.000000     29
# 1385.000000     28
# 1155.000000     27
# Name: weight_kg, Length: 100, dtype: int64

# %%
# df.weight_kg = df.groupby(["make", "model", "body_type"])["weight_kg"].apply(lambda x : x.fillna(x.mean() if any(x.mean()) else df.weight_kg.mean())).value_counts(dropna=False)

# %%
df.weight_kg.isnull().sum()
# Out:
# 6974

# %%
df.weight_kg.mean()
# Out:
# 1351.1065399664617

# %%
df.weight_kg.median()
# Out:
# 1288.0

# %%
# since there are much extreme values, we will fill with median

# %%
df["weight_kg"] = df.groupby(["make", "model", "body_type"])["weight_kg"].apply(lambda x : x.fillna(x.median() if (x.median() >= 1) else df["weight_kg"].median()))

# %%
df.weight_kg.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## drive_chain

# %%
check_df("drive_chain")
# Out:
# column name :  drive_chain
# --------------------------------
# Per_of_Nulls   :  % 43.08
# Num_of_Nulls   :  6858
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "body_type"])["drive_chain"].value_counts(dropna=False)
# Out:
# make     model   body_type    drive_chain
# Audi     A1      Compact      front          685
#                               NaN            352
#                               4WD              2
#                  Coupe        NaN              2
#                  Other        front           12
#                                             ...
# Renault  Espace  Transporter  front            6
#                               4WD              1
#                  Van          NaN            391
#                               front          374
#                               4WD             38
# Name: drive_chain, Length: 107, dtype: int64

# %%
df.drive_chain = df.groupby(["make", "model", "body_type"])["drive_chain"].apply(lambda x : x.fillna(x.mode()[0] if any(x.mode()) else df["drive_chain"].mode()[0]))

# %%
df.drive_chain.value_counts()
# Out:
# front    15711
# 4WD        204
# rear         4
# Name: drive_chain, dtype: int64

# %%
df.drive_chain.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## co2e_g

# %%
check_df("co2e_g")
# Out:
# column name :  co2e_g
# --------------------------------
# Per_of_Nulls   :  % 15.34
# Num_of_Nulls   :  2442
# NaN       2442
# 120.0      740
# 99.0       545
# 97.0       537
# 104.0      501
#           ...
# 160.0        1
# 331.0        1
# 990.0        1
# 1060.0       1
# 193.0        1
# Name: co2e_g, Length: 120, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "fuel"])["co2e_g"].value_counts(dropna=False)
# Out:
# make     model   fuel     co2e_g
# Audi     A1      Benzine  97.0      287
#                           NaN       238
#                           102.0     229
#                           108.0     195
#                           111.0     181
#                                    ...
# Renault  Espace  Diesel   191.0       2
#                           117.0       1
#                           122.0       1
#                           140.0       1
#                           174.0       1
# Name: co2e_g, Length: 516, dtype: int64

# %%
df.co2e_g.mean()
# Out:
# 123.79357423758997

# %%
df.co2e_g.median()
# Out:
# 116.0

# %%
df.co2e_g.sort_values()
# Out:
# 8110     14.0
# 3617     36.0
# 3612     36.0
# 3615     36.0
# 12547    45.0
#          ...
# 15883     NaN
# 15903     NaN
# 15906     NaN
# 15908     NaN
# 15909     NaN
# Name: co2e_g, Length: 15919, dtype: float64

# %%
df.co2e_g = df.groupby(["make", "model", "fuel"])["co2e_g"].apply(lambda x : x.fillna(x.median() if (x.median() > 13) else df["co2e_g"].median()))

# %% [markdown]
# ## emission_class

# %%
check_df("emission_class")
# Out:
# column name :  emission_class
# --------------------------------
# Per_of_Nulls   :  % 22.79
# Num_of_Nulls   :  3628
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "fuel", "age"])["emission_class"].value_counts().head(20)
# Out:
# make  model  fuel     age  emission_class
# Audi  A1     Benzine  0.0  Euro 6            266
#                            Euro 6d-TEMP      264
#                            Euro 6d             5
#                       1.0  Euro 6            323
#                            Euro 6d-TEMP       11
#                            Euro 5              3
#                       2.0  Euro 6            213
#                            Euro 5              1
#                       3.0  Euro 6            257
#                            Euro 6d-TEMP        3
#                            Euro 4              1
#              Diesel   0.0  Euro 6              3
#                       1.0  Euro 6            295
#                            Euro 5              1
#                       2.0  Euro 6            133
#                       3.0  Euro 6            269
#                            Euro 5              4
#                            Euro 6c             2
#       A2     Diesel   1.0  Euro 6              1
#       A3     Benzine  0.0  Euro 6d-TEMP      222
# Name: emission_class, dtype: int64

# %%
df.groupby(["make", "model", "fuel", "age"])["emission_class"].value_counts().tail(20)
# Out:
# make     model   fuel     age  emission_class
# Renault  Espace  Benzine  1.0  Euro 6d-TEMP        3
#                                Euro 4              1
#                                Euro 6c             1
#                           2.0  Euro 6             38
#                                Euro 5              1
#                           3.0  Euro 6             29
#                  Diesel   0.0  Euro 6             49
#                                Euro 6d-TEMP       39
#                                Euro 6c             2
#                                Euro 6d             2
#                           1.0  Euro 6             97
#                                Euro 6c             3
#                                Euro 6d             2
#                           2.0  Euro 6             74
#                                Euro 6c             1
#                           3.0  Euro 6            197
#                                Euro 6d-TEMP        3
#                                Euro 5              1
#                                Euro 6c             1
#                                Euro 6d             1
# Name: emission_class, dtype: int64

# %%
df["emission_class"] = df.groupby(["make", "model", "fuel", "age"])["emission_class"].fillna(method="bfill").fillna(method="ffill")

# %% [markdown]
# ## comfort&convenience

# %%
check_df("comfort&convenience")
# Out:
# column name :  comfort&convenience
# --------------------------------
# Per_of_Nulls   :  % 5.78
# Num_of_Nulls   :  920
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   216
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                               134
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                                       130
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                   105
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Split rear seats,Start-stop system,Tinted windows                                                                                                                                                                                                           1
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof                                                                                                1
# Air conditioning,Armrest,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Split rear seats,Start-stop system,Tinted windows                                                                                                                 1
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating                                                                                                                                                                                                                1
# Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof      1
# Name: comfort&convenience, Length: 6199, dtype: int64
# ******************************

# %%
df["comfort&convenience"] = df.groupby(["make", "model", "age", "body_type"])["comfort&convenience"].fillna(method="pad").fillna(method="backfill")

# %%
df["comfort&convenience"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## entertainment&media

# %%
check_df("entertainment&media")
# Out:
# column name :  entertainment&media
# --------------------------------
# Per_of_Nulls   :  % 8.63
# Num_of_Nulls   :  1374
# NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# CD player,Hands-free equipment,MP3,Radio,USB                                                           1
# MP3,Radio,Sound system,USB                                                                             1
# Bluetooth,MP3,On-board computer,Radio,Television,USB                                                   1
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,Television,USB       1
# Name: entertainment&media, Length: 347, dtype: int64
# ******************************

# %%
 df["entertainment&media"] = df.groupby(["make", "model", "age", "body_type"])["entertainment&media"].fillna(method="pad").fillna(method="backfill")

# %%
df["entertainment&media"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## extras

# %%
# df[ df.extras.str.contains("Alloy wheels") if ~df.extras.isnull() else False ]

# %%
check_df("extras")
# Out:
# column name :  extras
# --------------------------------
# Per_of_Nulls   :  % 18.61
# Num_of_Nulls   :  2962
# Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch                            1
# Alloy wheels,Catalytic Converter,Ski bag,Sport package,Voice Control                                          1
# Catalytic Converter,Roof rack,Sport seats,Sport suspension                                                    1
# Alloy wheels,Shift paddles,Ski bag,Sport seats,Sport suspension,Touch screen,Voice Control                    1
# Name: extras, Length: 660, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "age", "body_type"])["extras"].value_counts(dropna=False)
# Out:
# make     model   age  body_type  extras
# Audi     A1      0.0  Compact    Alloy wheels                                                          65
#                                  NaN                                                                   57
#                                  Alloy wheels,Catalytic Converter,Voice Control                        54
#                                  Alloy wheels,Voice Control                                            51
#                                  Alloy wheels,Catalytic Converter                                      15
#                                                                                                        ..
# Renault  Espace  3.0  Van        Alloy wheels,Sport seats,Trailer hitch,Voice Control                   1
#                                  Alloy wheels,Sport suspension,Touch screen                             1
#                                  Alloy wheels,Sport suspension,Touch screen,Voice Control               1
#                                  Alloy wheels,Touch screen,Trailer hitch,Voice Control,Winter tyres     1
#                                  Sport seats                                                            1
# Name: extras, Length: 2845, dtype: int64

# %%
 df["extras"] = df.groupby(["make", "model", "age", "body_type"])["extras"].fillna(method="pad").fillna(method="backfill")

# %%
df.extras.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## safety&security

# %%
check_df("safety&security")
# Out:
# column name :  safety&security
# --------------------------------
# Per_of_Nulls   :  % 6.17
# Num_of_Nulls   :  982
# NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                 480
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                275
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                           272
#                                                                                                                                                                                                                                                                                                                                                                  ...
# ABS,Central door lock,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag                                                                                                                                                                                                                                              1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                 1
# ABS,Adaptive Cruise Control,Alarm system,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Power steering,Tire pressure monitoring system,Traction control                                                                                                                                                  1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition      1
# Name: safety&security, Length: 4444, dtype: int64
# ******************************

# %%
 df["safety&security"] = df.groupby(["make", "model", "age", "body_type"])["safety&security"].fillna(method="pad").fillna(method="backfill")

# %%
df["safety&security"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## gears

# %%
check_df("gears")
# Out:
# column name :  gears
# --------------------------------
# Per_of_Nulls   :  % 29.6
# Num_of_Nulls   :  4712
# 6.0     5822
# NaN     4712
# 5.0     3239
# 7.0     1908
# 8.0      224
# 9.0        6
# 1.0        2
# 3.0        2
# 4.0        2
# 2.0        1
# 50.0       1
# Name: gears, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "body_type"])["gears"].value_counts()
# Out:
# make     model   body_type  gears
# Audi     A1      Compact    5.0      280
#                             7.0      202
#                             6.0       83
#                             8.0        1
#                  Coupe      5.0        1
#                                     ...
# Renault  Espace  Van        6.0      359
#                             7.0      105
#                             9.0        6
#                             3.0        2
#                             4.0        2
# Name: gears, Length: 102, dtype: int64

# %%
df.groupby(["make", "model", "body_type"])["gears"].fillna(method="ffill").fillna(method = "bfill").value_counts()
# Out:
# 6.0     8370
# 5.0     4398
# 7.0     2843
# 8.0      288
# 9.0       11
# 3.0        3
# 1.0        2
# 4.0        2
# 2.0        1
# 50.0       1
# Name: gears, dtype: int64

# %%
df.groupby(["make", "model", "body_type"])["gears"].apply(lambda x : x.fillna(x.mode()[0] if any(x.mode()) else df.gears.mode()[0])).value_counts()
# Out:
# 6.0     8411
# 5.0     5359
# 7.0     1911
# 8.0      224
# 9.0        6
# 1.0        2
# 3.0        2
# 4.0        2
# 2.0        1
# 50.0       1
# Name: gears, dtype: int64

# %%
df.gears = df.groupby(["make", "model", "body_type"])["gears"].fillna(method="ffill").fillna(method = "bfill")

# %%
df.gears.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## country_version

# %%
check_df("country_version")
# Out:
# column name :  country_version
# --------------------------------
# Per_of_Nulls   :  % 52.35
# Num_of_Nulls   :  8333
# NaN               8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64
# ******************************

# %%
df.groupby(["make", "model", "body_type", "vat"])["country_version"].value_counts(dropna=False).head(60)
# Out:
# make  model  body_type      vat               country_version
# Audi  A1     Compact        Price negotiable  Germany             11
#                                               NaN                  8
#                                               Netherlands          3
#                             VAT deductible    Germany            437
#                                               NaN                418
#                                               Netherlands         65
#                                               European Union      58
#                                               Denmark             15
#                                               Italy                8
#                                               Austria              5
#                                               Belgium              5
#                                               France               2
#                                               Poland               2
#                                               Romania              1
#                                               Spain                1
#              Coupe          VAT deductible    NaN                  2
#              Other          VAT deductible    NaN                  7
#                                               Italy                5
#                                               Germany              1
#              Sedans         Price negotiable  NaN                113
#                                               Italy               11
#                                               Germany              5
#                                               Austria              1
#                                               Belgium              1
#                                               Spain                1
#                                               Switzerland          1
#                             VAT deductible    NaN                835
#                                               Germany            309
#                                               Italy              132
#                                               Spain               60
#                                               Belgium             42
#                                               Austria             13
#                                               European Union       9
#                                               France               3
#                                               Luxembourg           1
#                                               Slovakia             1
#              Station wagon  VAT deductible    NaN                 16
#                                               Germany              4
#                                               Spain                1
#              Van            VAT deductible    NaN                  1
#       A2     Off-Road       VAT deductible    Germany              1
#       A3     Compact        Price negotiable  NaN                  2
#                                               Netherlands          2
#                                               Italy                1
#                             VAT deductible    NaN                129
#                                               Netherlands         31
#                                               Belgium             12
#                                               Germany              3
#                                               Austria              2
#              Convertible    Price negotiable  NaN                  1
#                                               Netherlands          1
#                             VAT deductible    NaN                  3
#                                               Italy                2
#                                               Netherlands          1
#              Coupe          Price negotiable  Italy                1
#                             VAT deductible    NaN                  2
#                                               Belgium              1
#              Other          Price negotiable  NaN                  2
#                             VAT deductible    NaN                 12
#                                               Italy                2
# Name: country_version, dtype: int64

# %%
df.country_version = df.country_version.fillna("Unknown")

# %%
df.country_version.isnull().sum()
# Out:
# 0

# %%
df.country_version.value_counts()
# Out:
# Unknown           8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64

# %% [markdown]
# ## consumption_comb, consumption_city, consumption_country

# %%
df[['consumption_comb', 'consumption_city','consumption_country']].isnull().sum()
# Out:
# consumption_comb       3790
# consumption_city       4039
# consumption_country    3365
# dtype: int64

# %%
df.consumption_comb.mean()
# Out:
# 4.860722235963347

# %%
df.consumption_city.mean()
# Out:
# 5.973047138047285

# %%
df.consumption_country.mean()
# Out:
# 4.214107057511512

# %%
# ratio of relation between consumption_city and consumption_country is 0.38 and 0.62

# %%
df.groupby(['make','model','cylinders','weight_kg', 'body_type'])['consumption_city'].value_counts(dropna=False).head(60)
# Out:
# make  model  cylinders  weight_kg  body_type      consumption_city
# Audi  A1     3.0        102.0      Compact        5.6                  1
#                         1010.0     Compact        NaN                  2
#                                    Coupe          NaN                  2
#                         1035.0     Compact        NaN                  6
#                                    Sedans         NaN                  5
#                         1040.0     Compact        NaN                  1
#                                                   5.4                  1
#                         1060.0     Sedans         NaN                  2
#                         1065.0     Compact        5.4                 25
#                                                   5.5                  7
#                                                   NaN                  3
#                                                   5.6                  1
#                                    Sedans         5.4                  1
#                         1088.0     Sedans         NaN                  1
#                         1090.0     Compact        5.4                  6
#                                                   NaN                  3
#                                    Sedans         NaN                  2
#                                                   5.4                  2
#                         1094.0     Sedans         NaN                  1
#                         1097.0     Sedans         NaN                  4
#                         1100.0     Compact        5.4                  2
#                         1105.0     Compact        4.2                 10
#                                                   3.9                  2
#                                    Sedans         NaN                  1
#                         1110.0     Compact        NaN                 15
#                                                   5.2                  6
#                                    Sedans         NaN                 38
#                                                   5.2                  4
#                                                   6.2                  3
#                                                   4.7                  1
#                                                   5.1                  1
#                         1114.0     Sedans         NaN                  1
#                         1115.0     Sedans         NaN                  1
#                         1118.0     Sedans         NaN                  2
#                         1120.0     Sedans         3.9                  4
#                                                   NaN                  1
#                                                   4.2                  1
#                         1125.0     Sedans         NaN                  1
#                                    Station wagon  NaN                  1
#                         1130.0     Sedans         3.9                  3
#                                                   4.2                  1
#                         1133.0     Compact        5.8                  3
#                                    Sedans         NaN                  6
#                         1134.0     Compact        NaN                  6
#                                    Sedans         NaN                  2
#                                                   5.1                  1
#                                                   5.2                  1
#                         1135.0     Compact        5.2                 28
#                                                   NaN                 19
#                                                   5.1                  2
#                                                   5.4                  1
#                                                   5.5                  1
#                                                   6.2                  1
#                                    Sedans         NaN                 77
#                                                   5.2                 24
#                                                   6.2                  3
#                                                   5.1                  1
#                                                   5.4                  1
#                                    Station wagon  5.2                  1
#                         1136.0     Sedans         NaN                  2
# Name: consumption_city, dtype: int64

# %%
df.groupby(["make", "model", "cylinders", "weight_kg", "body_type", "fuel"])["consumption_city"].value_counts()
# Out:
# make     model   cylinders  weight_kg  body_type    fuel     consumption_city
# Audi     A1      3.0        102.0      Compact      Benzine  5.6                  1
#                             1040.0     Compact      Benzine  5.4                  1
#                             1065.0     Compact      Benzine  5.4                 25
#                                                              5.5                  7
#                                                              5.6                  1
#                                                                                  ..
# Renault  Espace  4.0        2037.0     Van          Diesel   6.2                  1
#                             2044.0     Sedans       Diesel   6.3                  1
#                             2353.0     Transporter  Diesel   5.1                 14
#                             2410.0     Transporter  Benzine  7.8                  3
#                             2471.0     Van          Diesel   5.1                  4
# Name: consumption_city, Length: 1869, dtype: int64

# %%
df[['consumption_comb', 'consumption_city','consumption_country']]
# Out:
#        consumption_comb  consumption_city  consumption_country
# 0                   3.8               4.3                  3.5
# 1                   5.6               7.1                  4.7
# 2                   3.8               4.4                  3.4
# 3                   3.8               4.3                  3.5
# 4                   4.1               4.6                  3.8
# ...                 ...               ...                  ...
# 15914               5.3               6.2                  4.7
# 15915               7.4               9.2                  6.3
# 15916               5.3               6.2                  4.7
# 15917               5.3               6.2                  4.7
# 15918               6.8               8.7                  5.7
#
# [15919 rows x 3 columns]

# %%
df["consumption_comb"] = df["consumption_comb"].fillna(abs(df["consumption_country"]*0.62 + df["consumption_city"]*0.38))

# %%
df.consumption_comb.value_counts()
# Out:
# 5.400    769
# 3.900    733
# 5.100    654
# 4.400    623
# 5.600    618
#         ...
# 7.500      1
# 3.780      1
# 5.074      1
# 4.282      1
# 5.098      1
# Name: consumption_comb, Length: 115, dtype: int64

# %%
df.consumption_comb.isnull().sum()
# Out:
# 2490

# %%
df["consumption_country"] = df["consumption_country"].fillna(abs((df["consumption_comb"] - df["consumption_city"]*0.38)/0.62))

# %%
df.consumption_country.isnull().sum()
# Out:
# 2876

# %%
df["consumption_city"] = df["consumption_city"].fillna(abs(df["consumption_comb"] - df["consumption_country"]*0.62)/0.38)

# %%
df.consumption_city.isnull().sum()
# Out:
# 2942

# %%
df.consumption_city = df.groupby(["make", "model", "body_type" ,"weight_kg", "cylinders", "fuel"])["consumption_city"].fillna(method="ffill").fillna(method="bfill")

# %%
df.consumption_city.isnull().sum()
# Out:
# 0

# %%
df.consumption_country = df.groupby(["make", "model", "body_type" ,"weight_kg", "cylinders", "fuel"])["consumption_country"].fillna(method="ffill").fillna(method="bfill")

# %%
df.consumption_country.isnull().sum()
# Out:
# 0

# %%
df["consumption_comb"] = df["consumption_comb"].fillna(abs(df["consumption_country"]*0.62 + df["consumption_city"]*0.38))

# %%
df.consumption_comb.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# body_type                 0
# price_€                   0
# vat                       0
# km                        0
# hp_kW                     0
# type                      0
# previous_owners           0
# warranty                  0
# make                      0
# model                     0
# body_color                0
# paint_type                0
# upholstery                0
# nr_of_doors               0
# nr_of_seats               0
# gearing_type              0
# engine_displacement_cc    0
# cylinders                 0
# weight_kg                 0
# drive_chain               0
# fuel                      0
# co2e_g                    0
# emission_class            0
# comfort&convenience       0
# entertainment&media       0
# extras                    0
# safety&security           0
# gears                     0
# country_version           0
# consumption_comb          0
# consumption_city          0
# consumption_country       0
# age                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_type               15919 non-null  object
#  1   price_€                 15919 non-null  float64
#  2   vat                     15919 non-null  object
#  3   km                      15919 non-null  float64
#  4   hp_kW                   15919 non-null  float64
#  5   type                    15919 non-null  object
#  6   previous_owners         15919 non-null  float64
#  7   warranty                15919 non-null  float64
#  8   make                    15919 non-null  object
#  9   model                   15919 non-null  object
#  10  body_color              15919 non-null  object
#  11  paint_type              15919 non-null  object
#  12  upholstery              15919 non-null  object
#  13  nr_of_doors             15919 non-null  float64
#  14  nr_of_seats             15919 non-null  float64
#  15  gearing_type            15919 non-null  object
#  16  engine_displacement_cc  15919 non-null  float64
#  17  cylinders               15919 non-null  float64
#  18  weight_kg               15919 non-null  float64
#  19  drive_chain             15919 non-null  object
#  20  fuel                    15919 non-null  object
#  21  co2e_g                  15919 non-null  float64
#  22  emission_class          15919 non-null  object
#  23  comfort&convenience     15919 non-null  object
#  24  entertainment&media     15919 non-null  object
#  25  extras                  15919 non-null  object
#  26  safety&security         15919 non-null  object
#  27  gears                   15919 non-null  float64
#  28  country_version         15919 non-null  object
#  29  consumption_comb        15919 non-null  float64
#  30  consumption_city        15919 non-null  float64
#  31  consumption_country     15919 non-null  float64
#  32  age                     15919 non-null  float64
# dtypes: float64(16), object(17)
# memory usage: 4.0+ MB

# %%
df["consumption_city"].sort_values(ascending=True).head(60)
# Out:
# 11553    0.321053
# 9756     0.710526
# 13008    1.589474
# 10755    1.663158
# 10758    1.663158
# 10759    1.663158
# 10764    1.673684
# 10870    1.673684
# 10866    1.673684
# 10860    1.673684
# 4936     1.805263
# 3483     1.805263
# 9268     2.178947
# 4026     2.294737
# 4741     2.294737
# 13680    2.447368
# 13678    2.447368
# 13679    2.447368
# 11503    2.784211
# 11504    2.784211
# 11596    2.784211
# 12068    2.784211
# 11088    2.784211
# 11065    2.784211
# 10811    2.784211
# 2245     3.057895
# 13356    3.300000
# 13355    3.300000
# 13354    3.300000
# 13353    3.300000
# 13352    3.300000
# 13349    3.300000
# 13347    3.300000
# 13357    3.300000
# 13312    3.300000
# 13309    3.300000
# 13307    3.300000
# 13579    3.300000
# 6153     3.300000
# 13348    3.300000
# 13358    3.300000
# 13360    3.300000
# 13518    3.300000
# 13523    3.300000
# 6160     3.300000
# 13715    3.300000
# 13501    3.300000
# 6159     3.300000
# 13716    3.300000
# 13721    3.300000
# 13442    3.300000
# 13668    3.300000
# 13369    3.300000
# 13366    3.300000
# 13861    3.300000
# 13365    3.300000
# 13362    3.300000
# 13361    3.300000
# 13359    3.300000
# 13351    3.300000
# Name: consumption_city, dtype: float64

# %%
df.iloc[[10764, 10755]]
# Out:
#       body_type  price_€             vat        km  hp_kW  type  \
# 10764    Sedans  12100.0  VAT deductible  103000.0   92.0  Used
# 10755    Sedans  11700.0  VAT deductible  107000.0   92.0  Used
#
#        previous_owners  warranty  make     model body_color paint_type  \
# 10764              1.0       1.0  Opel  Insignia      Black   Metallic
# 10755              1.0       1.0  Opel  Insignia      White   Metallic
#
#       upholstery  nr_of_doors  nr_of_seats gearing_type  \
# 10764      Cloth          5.0          5.0    Automatic
# 10755      Cloth          5.0          5.0    Automatic
#
#        engine_displacement_cc  cylinders  weight_kg drive_chain    fuel  \
# 10764                  1956.0        4.0     1503.0       front  Diesel
# 10755                  1956.0        4.0     1503.0       front  Diesel
#
#        co2e_g emission_class comfort&convenience      entertainment&media  \
# 10764   147.0         Euro 6       Power windows  On-board computer,Radio
# 10755   164.0         Euro 6       Power windows  On-board computer,Radio
#
#              extras                                    safety&security  gears  \
# 10764  Alloy wheels  ABS,Central door lock,Driver-side airbag,Immob...    6.0
# 10755  Alloy wheels  ABS,Central door lock,Driver-side airbag,Immob...    6.0
#
#       country_version  consumption_comb  consumption_city  \
# 10764         Unknown               4.2          1.673684
# 10755         Unknown               4.7          1.663158
#
#        consumption_country  age
# 10764                  7.8  2.0
# 10755                  8.6  2.0

# %%
pd.set_option('display.max_rows', 130)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   body_type               15919 non-null  object
#  1   price_€                 15919 non-null  float64
#  2   vat                     15919 non-null  object
#  3   km                      15919 non-null  float64
#  4   hp_kW                   15919 non-null  float64
#  5   type                    15919 non-null  object
#  6   previous_owners         15919 non-null  float64
#  7   warranty                15919 non-null  float64
#  8   make                    15919 non-null  object
#  9   model                   15919 non-null  object
#  10  body_color              15919 non-null  object
#  11  paint_type              15919 non-null  object
#  12  upholstery              15919 non-null  object
#  13  nr_of_doors             15919 non-null  float64
#  14  nr_of_seats             15919 non-null  float64
#  15  gearing_type            15919 non-null  object
#  16  engine_displacement_cc  15919 non-null  float64
#  17  cylinders               15919 non-null  float64
#  18  weight_kg               15919 non-null  float64
#  19  drive_chain             15919 non-null  object
#  20  fuel                    15919 non-null  object
#  21  co2e_g                  15919 non-null  float64
#  22  emission_class          15919 non-null  object
#  23  comfort&convenience     15919 non-null  object
#  24  entertainment&media     15919 non-null  object
#  25  extras                  15919 non-null  object
#  26  safety&security         15919 non-null  object
#  27  gears                   15919 non-null  float64
#  28  country_version         15919 non-null  object
#  29  consumption_comb        15919 non-null  float64
#  30  consumption_city        15919 non-null  float64
#  31  consumption_country     15919 non-null  float64
#  32  age                     15919 non-null  float64
# dtypes: float64(16), object(17)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("filled_autoscout.csv", index=False)
